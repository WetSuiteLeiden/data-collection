# %% [markdown]
# # Creating a smaller raw-data datasets
#
# We would like to make a dataset with a smallish selection, of the raw data, probably just XML.

# %%
import collections

import wetsuite.helpers.notebook
import wetsuite.helpers.localdata
import wetsuite.helpers.koop_parse
import wetsuite.helpers.date
import wetsuite.helpers.format

# %%
# previously fetched
op_fetched             = wetsuite.helpers.localdata.LocalKV( 'op_fetched.db', str, bytes )

# %% [markdown]
# From this set, the most interesting might be:
# - **kamerstukken**, which belong to dossiers
# - **handelingen**, which may relate to multiple dossiers, or none (most seem _not_ to belong to dossiers), consider e.g.
#   - https://repository.overheid.nl/frbr/officielepublicaties/h-tk/20162017/h-tk-20162017-55-37/1/metadata/metadata.xml
#   - https://repository.overheid.nl/frbr/officielepublicaties/h-tk/19981999/h-tk-19981999-2741-2768/1/metadata/metadata.xml
# - **aanhangsels (bij de handelingen)**, which do not belong to dossiers
#
# Also, it'll be a mix of tweede kamer, eerste kamer, and verenigde vergaderingen, which brings a few more bordercases.

# %% [markdown]
# ### Considering dossiers
#
# Just sampling recent documents by date would break up kamerstuk-dossiers,
# and there are probably various questions that would care about complete dossiers.
#
# So we would probably care to select, say,
# - kamerstukdossier that have had recent activity
#   - ...though note that because these are often the more frequently updated, will also be many of the largest
# - handelingen that are recent and/or belong to that chosen set - which presumably has strong overlap
# - aanhangsels that are recent
#
# We can later choose to throw them in the same pile, or not.

# %% [markdown]
# In this process we will probably dig into the metadata more than once, so let's make that easier to read out - we
# - create a map from id to a metadata dict
# - create a map from id to the URL to the content URL (which is something we can fetch from op_fetched) (also, we basically already did that above)

# %%
# takes all URLs fetched into the store,
#   groups metadata and corresponding content item,   like  { 'kst-29692-26' -> {'metadata':'anurl', 'xml':'anurl'} } 
docmeta_groups        = collections.defaultdict( dict )

for fetched_url in op_fetched.keys():
    try:
        parsed_url = wetsuite.helpers.koop_parse.parse_repo_url( fetched_url ) # take useful things out of that URL
        doc_id   = parsed_url['doc_id']    # e.g. 'kst-29692-26'
        exprtype = parsed_url['exprtype']  # e.g. 'pdf' or 'xml'

        docmeta_groups[doc_id][exprtype] = fetched_url   # and put it in that data structure as mentioned
    except ValueError as ve:
        print('IGNORE: ', ve)
# Out:
# IGNORE:  ERROR understanding 'https://repository.overheid.nl/frbr/officielepublicaties/gmb/2018/gmb-2018-118956/1/html/gmb-2018-118956..html'

# %%
# Decisions for each ID will dig into more detailed metadata, so should probably parse _all_ metadata
#   ...which, note, is note: parsing five million stored files may take maybe twenty minutes)
# Note that we are ignoring PDFs for now, hoping there is XML data for most of these, 
#   ...which for these areas happens to be a workable assumption

# More concretely, we fill:
import wetsuite.helpers.etree


id_meta    = collections.defaultdict(dict) # id -> parsed metadata dict
id_xmlurl  = {}                            # id -> URL of the data XML

for doc_id in wetsuite.helpers.notebook.ProgressBar(docmeta_groups): # progress bar to get an idea of how long it will take
    if 'metadata' in docmeta_groups[doc_id]  and  'xml' in docmeta_groups[doc_id]: # ignore cases without metadata and XML
        try:
            meta_url = docmeta_groups[doc_id]['metadata']
            meta_bytes = op_fetched.get(meta_url)
            meta_list = wetsuite.helpers.koop_parse.parse_op_metafile( meta_bytes )
            id_xmlurl[doc_id] = docmeta_groups[doc_id]['xml']
            for metakey,schema,value in meta_list:
                id_meta[doc_id][metakey] = value # WARNING: for any duplicate keys this _will_ overwrite
        except wetsuite.helpers.etree.lxml.etree.XMLSyntaxError as xse:
            print( 'PARSE ERROR', meta_url, meta_bytes )

# %% [markdown]
# #### kst
#
# What next?
#
# Let's address the part with the most work first: kamerstukken and their dossiers.
#
# Since we want to select a smallish set, and probably prefer recent content, let's figure out dates and sizes of documents within each dossier.

# %%
doc_ids = list( id_meta.keys() )

dossier_dates     = collections.defaultdict( list )
dossier_bytesizes = collections.defaultdict( list )
dossier_doc_ids   = collections.defaultdict( list )

for doc_id in doc_ids:
    meta = id_meta[doc_id]
    if 'dossiernummer' in meta: # will be true for kamerstukken -- but also blg, h-ek, h-tk (VERIFY), so:
        if doc_id.startswith('kst-'):
            for dossiernummer in meta['dossiernummer'].split(';'): # split because that can actually be a list
                if 'available' in meta:
                    dossier_dates[     dossiernummer ].append( wetsuite.helpers.date.parse( meta['available'] ) )
                    dossier_bytesizes[ dossiernummer ].append( len( op_fetched.get( id_xmlurl[doc_id] )) )
                    dossier_doc_ids[   dossiernummer ].append( doc_id )

# %%
dossier_dates        # probably run only if you care about checking intermediates

# %%
dossier_bytesizes    # probably run only if you care about checking intermediates

# %%
# sort dossier identifiers, by the date of the most recent document in it
#   ...with the intent of later choosing the most recently added-to dossiers 
#      until we've reaced a particular size
dossier_maxdate = list( (dn, max(dates))  for dn, dates in dossier_dates.items() )
dossier_maxdate.sort(key = lambda p:p[1], reverse=True )

# %%
dossier_maxdate      # probably run only if you care about checking intermediates
# Out:
# [('31839', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('25295', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('31066', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('21501-08', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('33037', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('30252', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('32140', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('36546', datetime.datetime(2025, 3, 28, 0, 0)),
#  ('32847', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('28676', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('21501-28', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('34293', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('36600-VIII', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('36626', datetime.datetime(2025, 3, 27, 0, 0)),
#  ('27625', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('29237', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('24587', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('32317', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('22112', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('21501-20', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('22026', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('27020', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('27925', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('33576', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('21501-07', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('21501-31', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('32813', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('29023', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('35334', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('32637', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('27565', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('29362', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('31293', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('29665', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('31289', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('32645', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('30950', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('29826', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('31532', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36600', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('30952', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('35646', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36468', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36449', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36574', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36600-A', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36600-L', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('36638', datetime.datetime(2025, 3, 26, 0, 0)),
#  ('26448', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('26643', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('32761', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('30821', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('29477', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('28286', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('31305', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('32852', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('29398', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('31765', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('33835', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('32647', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36327', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36600-B', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('31083', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36600-IV', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('33047', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('33527', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('33839', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36344', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36413', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36584', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36600-VI', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36682', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36710', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('36711', datetime.datetime(2025, 3, 25, 0, 0)),
#  ('29911', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('29544', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('19637', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('21501-32', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('27858', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('32793', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('29689', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('29683', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('29323', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('26488', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('27830', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('32011', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('33118', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('31516', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('36600-XVII', datetime.datetime(2025, 3, 24, 0, 0)),
#  ('35295', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('30872', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('31477', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('29517', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('29628', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('31936', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('32545', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('35749', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('36353', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('36410-XIV', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('36588', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('36600-XVI', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('36709', datetime.datetime(2025, 3, 21, 0, 0)),
#  ('25883', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('31288', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('33626', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('32805', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('24077', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('34104', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('25087', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('33328', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('31865', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('28362', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('32634', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('35483', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('35112', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36243', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36450', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36502', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36561', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36582', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('36700', datetime.datetime(2025, 3, 20, 0, 0)),
#  ('29754', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('29282', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('21501-02', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('29383', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36180', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('21501-33', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('29684', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('29697', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('31490', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('32802', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('29232', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36108', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('28973', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36151', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('33335', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('35247', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36125', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36636', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36600-VII', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36600-XX', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36699', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36707', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36708', datetime.datetime(2025, 3, 19, 0, 0)),
#  ('36045', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('30175', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('21501-34', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('29389', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('31524', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('25422', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('30015', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('29924', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36578', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('35561', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36176', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36516', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36649', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36702', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('36706', datetime.datetime(2025, 3, 18, 0, 0)),
#  ('31409', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('29247', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('33450', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('30196', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('27924', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('26485', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('33763', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('33529', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('29509', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('30462', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('32034', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('33695', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('34861', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('35728', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36154', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36335', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36600-IX', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36615', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36672', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36677', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36683', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('36688-(R2205)', datetime.datetime(2025, 3, 17, 0, 0)),
#  ('CXLVI', datetime.datetime(2025, 3, 14, 0, 0)),
#  ('34153', datetime.datetime(2025, 3, 14, 0, 0)),
#  ('36512', datetime.datetime(2025, 3, 14, 0, 0)),
#  ('36600-I', datetime.datetime(2025, 3, 14, 0, 0)),
#  ('30573', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('23432', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('32127', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('27529', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('32827', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('34843', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('36067', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('36600-V', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('31482', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('35672', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('36600-XIII', datetime.datetime(2025, 3, 13, 0, 0)),
#  ('30420', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('21501-30', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('25268', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('27923', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('25424', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('24724', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('31015', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('33836', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('29838', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36600-XIV', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36486', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36541', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36600-XV', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36703', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36704', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('36705', datetime.datetime(2025, 3, 12, 0, 0)),
#  ('22343', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('21109', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('32043', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('36121', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('28844', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('36163', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('36365', datetime.datetime(2025, 3, 11, 0, 0)),
#  ('33552', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('29279', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('29984', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('29893', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('31521', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('32820', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('28741', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('31311', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36446', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('34244', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('27428', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('33652', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('33561', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36196', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36332', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36378', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36395', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36600-XII', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36600-XXII', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('36684', datetime.datetime(2025, 3, 10, 0, 0)),
#  ('CXLVII', datetime.datetime(2025, 3, 7, 0, 0)),
#  ('36618', datetime.datetime(2025, 3, 7, 0, 0)),
#  ('36349', datetime.datetime(2025, 3, 6, 0, 0)),
#  ('36579', datetime.datetime(2025, 3, 6, 0, 0)),
#  ('31575', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('32013', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('31239', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('29538', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('31753', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('31265', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('35990', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('36300', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('36639', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('36701', datetime.datetime(2025, 3, 5, 0, 0)),
#  ('30351', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('32404', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('30806', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('34682', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('32735', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('35851', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('36190', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('36410-VII', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('36565', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('36600-C', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('36671', datetime.datetime(2025, 3, 4, 0, 0)),
#  ('30234', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36600-XXIII', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36566', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('34430', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('35386', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('35968', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36410-XIII', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36410-B', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36513', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36555', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('36598', datetime.datetime(2025, 3, 3, 0, 0)),
#  ('27859', datetime.datetime(2025, 2, 28, 0, 0)),
#  ('28625', datetime.datetime(2025, 2, 28, 0, 0)),
#  ('29861', datetime.datetime(2025, 2, 28, 0, 0)),
#  ('36668', datetime.datetime(2025, 2, 28, 0, 0)),
#  ('24515', datetime.datetime(2025, 2, 27, 0, 0)),
#  ('36481', datetime.datetime(2025, 2, 27, 0, 0)),
#  ('29325', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('24095', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('21501-04', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('32429', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('22054', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('34252', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('29963', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('34990', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('36552', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('36640-(R2201)', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('36679', datetime.datetime(2025, 2, 26, 0, 0)),
#  ('30696', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('20361', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('24446', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('22452', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('28684', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('26150', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('31793', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('33321', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('33694', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('33799', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('35367', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('36551', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('36665', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('36666', datetime.datetime(2025, 2, 25, 0, 0)),
#  ('24804', datetime.datetime(2025, 2, 24, 0, 0)),
#  ('34324', datetime.datetime(2025, 2, 24, 0, 0)),
#  ('36600-III', datetime.datetime(2025, 2, 24, 0, 0)),
#  ('30012', datetime.datetime(2025, 2, 21, 0, 0)),
#  ('29453', datetime.datetime(2025, 2, 21, 0, 0)),
#  ('32336', datetime.datetime(2025, 2, 21, 0, 0)),
#  ('36471', datetime.datetime(2025, 2, 21, 0, 0)),
#  ('36537', datetime.datetime(2025, 2, 21, 0, 0)),
#  ('25223', datetime.datetime(2025, 2, 20, 0, 0)),
#  ('36670', datetime.datetime(2025, 2, 20, 0, 0)),
#  ('36689', datetime.datetime(2025, 2, 20, 0, 0)),
#  ('36690', datetime.datetime(2025, 2, 20, 0, 0)),
#  ('36691', datetime.datetime(2025, 2, 20, 0, 0)),
#  ('35534', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('36460', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('36535', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('36602', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('36648', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('36680', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('CLXX', datetime.datetime(2025, 2, 19, 0, 0)),
#  ('28663', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('24557', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('35746', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('31571', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('36221', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('36600-X', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('36698', datetime.datetime(2025, 2, 18, 0, 0)),
#  ('31322', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('23645', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('32623', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('26956', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('29668', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('32648', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('36549', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('36674', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('36686', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('36697', datetime.datetime(2025, 2, 17, 0, 0)),
#  ('31568', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('33996', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('34655', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('35482', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('36600-K', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('36600-M', datetime.datetime(2025, 2, 14, 0, 0)),
#  ('20043', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('22660', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('23908-(R1519)', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('34808', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('35403', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('36357', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('36592', datetime.datetime(2025, 2, 13, 0, 0)),
#  ('28638', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('21501-03', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('31934', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('30139', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('28694', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('35734', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('36280', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('36284', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('36641', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('36692', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('36696', datetime.datetime(2025, 2, 12, 0, 0)),
#  ('35447', datetime.datetime(2025, 2, 11, 0, 0)),
#  ('36624', datetime.datetime(2025, 2, 11, 0, 0)),
#  ('36663', datetime.datetime(2025, 2, 11, 0, 0)),
#  ('36675', datetime.datetime(2025, 2, 11, 0, 0)),
#  ('36676', datetime.datetime(2025, 2, 11, 0, 0)),
#  ('34352', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('32824', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('29936', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('28345', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('33202', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('36287', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('36600-IIA', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('36600-IIB', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('36694-(R2206)', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('36695-(R2207)', datetime.datetime(2025, 2, 10, 0, 0)),
#  ('29427', datetime.datetime(2025, 2, 7, 0, 0)),
#  ('35455', datetime.datetime(2025, 2, 7, 0, 0)),
#  ('36021', datetime.datetime(2025, 2, 7, 0, 0)),
#  ('36372', datetime.datetime(2025, 2, 7, 0, 0)),
#  ('28807', datetime.datetime(2025, 2, 6, 0, 0)),
#  ('28089', datetime.datetime(2025, 2, 6, 0, 0)),
#  ('32849', datetime.datetime(2025, 2, 6, 0, 0)),
#  ('32398', datetime.datetime(2025, 2, 6, 0, 0)),
#  ('36693', datetime.datetime(2025, 2, 6, 0, 0)),
#  ('29338', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('29240', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('33578', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('32033', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('33223', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('36625-XVI', datetime.datetime(2025, 2, 5, 0, 0)),
#  ('27879', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('25657', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('25764', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('29352', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('34477', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('34986', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('35101', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('35210-VI', datetime.datetime(2025, 2, 4, 0, 0)),
#  ('24170', datetime.datetime(2025, 2, 3, 0, 0)),
#  ('35396', datetime.datetime(2025, 2, 3, 0, 0)),
#  ('35867', datetime.datetime(2025, 2, 3, 0, 0)),
#  ('36667', datetime.datetime(2025, 2, 3, 0, 0)),
#  ('30010', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('35532', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('35533', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('36294', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('36581', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('36625-A', datetime.datetime(2025, 1, 31, 0, 0)),
#  ('32716', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('36507', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('32725', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('35594', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('36326', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('36557', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('36687', datetime.datetime(2025, 1, 30, 0, 0)),
#  ('29515', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('27406', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('29614', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('35600', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('36412', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('36575', datetime.datetime(2025, 1, 29, 0, 0)),
#  ('27622', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('32668', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('35423', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('36137', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('36545', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('36547', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('36583', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('36685', datetime.datetime(2025, 1, 28, 0, 0)),
#  ('28642', datetime.datetime(2025, 1, 27, 0, 0)),
#  ('35384', datetime.datetime(2025, 1, 27, 0, 0)),
#  ('36387', datetime.datetime(2025, 1, 27, 0, 0)),
#  ('22159', datetime.datetime(2025, 1, 27, 0, 0)),
#  ('32252', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36094', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36159', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36536', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36600-J', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-B', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-C', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-IIA', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-IIB', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-III', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-IV', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-J', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-K', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-L', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-V', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-VII', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-XIII', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-X', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-XIV', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-XV', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('36625-XVII', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('CLXIV', datetime.datetime(2025, 1, 23, 0, 0)),
#  ('29653', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('29270', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36410', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('32861', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36225', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36465', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36612', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36625-IX', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('36625-VIII', datetime.datetime(2025, 1, 22, 0, 0)),
#  ('23530', datetime.datetime(2025, 1, 21, 0, 0)),
#  ('30079', datetime.datetime(2025, 1, 21, 0, 0)),
#  ('35165', datetime.datetime(2025, 1, 21, 0, 0)),
#  ('31935', datetime.datetime(2025, 1, 21, 0, 0)),
#  ('36521', datetime.datetime(2025, 1, 21, 0, 0)),
#  ('25232', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('29502', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('29296', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('34997', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('32698', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('34775', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('36489', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('36527', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('36655', datetime.datetime(2025, 1, 20, 0, 0)),
#  ('33009', datetime.datetime(2025, 1, 17, 0, 0)),
#  ('31710', datetime.datetime(2025, 1, 17, 0, 0)),
#  ('36611', datetime.datetime(2025, 1, 17, 0, 0)),
#  ('26991', datetime.datetime(2025, 1, 16, 0, 0)),
#  ('35741', datetime.datetime(2025, 1, 16, 0, 0)),
#  ('36681', datetime.datetime(2025, 1, 16, 0, 0)),
#  ('28498', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('32620', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36382', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('33199', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('30072', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('34284', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('32859', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('35925-VI', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36514', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36625-VI', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36625-XII', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36664', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('36678', datetime.datetime(2025, 1, 15, 0, 0)),
#  ('31985', datetime.datetime(2025, 1, 14, 0, 0)),
#  ('34225', datetime.datetime(2025, 1, 14, 0, 0)),
#  ('36416', datetime.datetime(2025, 1, 14, 0, 0)),
#  ('28165', datetime.datetime(2025, 1, 10, 0, 0)),
#  ('36476', datetime.datetime(2025, 1, 10, 0, 0)),
#  ('31271', datetime.datetime(2025, 1, 10, 0, 0)),
#  ('34773', datetime.datetime(2025, 1, 10, 0, 0)),
#  ('36441', datetime.datetime(2025, 1, 10, 0, 0)),
#  ('33279', datetime.datetime(2025, 1, 9, 0, 0)),
#  ('33816', datetime.datetime(2025, 1, 9, 0, 0)),
#  ('35122', datetime.datetime(2025, 1, 9, 0, 0)),
#  ('36531', datetime.datetime(2025, 1, 9, 0, 0)),
#  ('36418', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('28325', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('35207', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('34309', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('35501', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('36222', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('35687', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('35688-(R2151)', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('36274', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('CLXV', datetime.datetime(2025, 1, 8, 0, 0)),
#  ('34109', datetime.datetime(2025, 1, 7, 0, 0)),
#  ('36228', datetime.datetime(2025, 1, 7, 0, 0)),
#  ('36635', datetime.datetime(2025, 1, 7, 0, 0)),
#  ('35754', datetime.datetime(2025, 1, 6, 0, 0)),
#  ('34931', datetime.datetime(2024, 12, 31, 0, 0)),
#  ('35527', datetime.datetime(2024, 12, 31, 0, 0)),
#  ('36247', datetime.datetime(2024, 12, 31, 0, 0)),
#  ('36394', datetime.datetime(2024, 12, 31, 0, 0)),
#  ('35709', datetime.datetime(2024, 12, 27, 0, 0)),
#  ('35756', datetime.datetime(2024, 12, 27, 0, 0)),
#  ('31560', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('26407', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('29664', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('33043', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('30373', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('34257', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('36341', datetime.datetime(2024, 12, 24, 0, 0)),
#  ('20454', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('29675', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('31757', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('34487', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('36142', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('36657', datetime.datetime(2024, 12, 23, 0, 0)),
#  ('22861', datetime.datetime(2024, 12, 20, 0, 0)),
#  ('35824', datetime.datetime(2024, 12, 20, 0, 0)),
#  ('30111', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('31476', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('36444', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('36617', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('36625', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('36673', datetime.datetime(2024, 12, 19, 0, 0)),
#  ('31475', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('35420', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('26234', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('36410-XII', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('27863', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('36614', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('32156', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('33532', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('35869', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('36594', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('36634', datetime.datetime(2024, 12, 18, 0, 0)),
#  ('35393', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('32239', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('33159', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('36526', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('36669', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('36643-(R2202)', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('36644', datetime.datetime(2024, 12, 17, 0, 0)),
#  ('27926', datetime.datetime(2024, 12, 16, 0, 0)),
#  ('22718', datetime.datetime(2024, 12, 16, 0, 0)),
#  ('32279', datetime.datetime(2024, 12, 16, 0, 0)),
#  ('28760', datetime.datetime(2024, 12, 16, 0, 0)),
#  ('33358', datetime.datetime(2024, 12, 16, 0, 0)),
#  ('36200-V', datetime.datetime(2024, 12, 13, 0, 0)),
#  ('35574', datetime.datetime(2024, 12, 13, 0, 0)),
#  ('35612', datetime.datetime(2024, 12, 13, 0, 0)),
#  ('36601', datetime.datetime(2024, 12, 13, 0, 0)),
#  ('36604', datetime.datetime(2024, 12, 13, 0, 0)),
#  ('31777', datetime.datetime(2024, 12, 12, 0, 0)),
#  ('30486', datetime.datetime(2024, 12, 12, 0, 0)),
#  ('35531', datetime.datetime(2024, 12, 12, 0, 0)),
#  ('36647-(R2204)', datetime.datetime(2024, 12, 12, 0, 0)),
#  ('23987', datetime.datetime(2024, 12, 11, 0, 0)),
#  ('34453', datetime.datetime(2024, 12, 11, 0, 0)),
#  ('34512', datetime.datetime(2024, 12, 11, 0, 0)),
#  ('35958', datetime.datetime(2024, 12, 11, 0, 0)),
#  ('36311', datetime.datetime(2024, 12, 10, 0, 0)),
#  ('36608', datetime.datetime(2024, 12, 10, 0, 0)),
#  ('36483', datetime.datetime(2024, 12, 10, 0, 0)),
#  ('36577', datetime.datetime(2024, 12, 10, 0, 0)),
#  ('36610', datetime.datetime(2024, 12, 10, 0, 0)),
#  ('29521', datetime.datetime(2024, 12, 9, 0, 0)),
#  ('31209', datetime.datetime(2024, 12, 9, 0, 0)),
#  ('33130', datetime.datetime(2024, 12, 9, 0, 0)),
#  ('CXIX', datetime.datetime(2024, 12, 9, 0, 0)),
#  ('33628', datetime.datetime(2024, 12, 6, 0, 0)),
#  ('27664', datetime.datetime(2024, 12, 6, 0, 0)),
#  ('34355', datetime.datetime(2024, 12, 6, 0, 0)),
#  ('36609', datetime.datetime(2024, 12, 6, 0, 0)),
#  ('33826', datetime.datetime(2024, 12, 5, 0, 0)),
#  ('36590', datetime.datetime(2024, 12, 5, 0, 0)),
#  ('36616', datetime.datetime(2024, 12, 5, 0, 0)),
#  ('30545', datetime.datetime(2024, 12, 4, 0, 0)),
#  ('29679', datetime.datetime(2024, 12, 4, 0, 0)),
#  ('34287', datetime.datetime(2024, 12, 4, 0, 0)),
#  ('36563', datetime.datetime(2024, 12, 4, 0, 0)),
#  ('36651', datetime.datetime(2024, 12, 4, 0, 0)),
#  ('35510', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('33495', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('36263', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('36277', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('36440', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('36495', datetime.datetime(2024, 12, 3, 0, 0)),
#  ('26049', datetime.datetime(2024, 12, 2, 0, 0)),
#  ('28479', datetime.datetime(2024, 12, 2, 0, 0)),
#  ('35238', datetime.datetime(2024, 12, 2, 0, 0)),
#  ('26122', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('33016', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('34400', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('36603', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('36605', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('36606', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('36607', datetime.datetime(2024, 11, 29, 0, 0)),
#  ('35123', datetime.datetime(2024, 11, 28, 0, 0)),
#  ('34332-(R2062)', datetime.datetime(2024, 11, 28, 0, 0)),
#  ('33997', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('34193', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('34588', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('36571', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('36597-(R2198)', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('36662', datetime.datetime(2024, 11, 27, 0, 0)),
#  ('31497', datetime.datetime(2024, 11, 26, 0, 0)),
#  ('34031', datetime.datetime(2024, 11, 26, 0, 0)),
#  ('36410-V', datetime.datetime(2024, 11, 26, 0, 0)),
#  ('36660', datetime.datetime(2024, 11, 26, 0, 0)),
#  ('36661', datetime.datetime(2024, 11, 26, 0, 0)),
#  ('36373', datetime.datetime(2024, 11, 25, 0, 0)),
#  ('35668', datetime.datetime(2024, 11, 25, 0, 0)),
#  ('35050', datetime.datetime(2024, 11, 25, 0, 0)),
#  ('36230', datetime.datetime(2024, 11, 21, 0, 0)),
#  ('32627', datetime.datetime(2024, 11, 21, 0, 0)),
#  ('32757', datetime.datetime(2024, 11, 21, 0, 0)),
#  ('36454', datetime.datetime(2024, 11, 21, 0, 0)),
#  ('36496', datetime.datetime(2024, 11, 20, 0, 0)),
#  ('36576', datetime.datetime(2024, 11, 20, 0, 0)),
#  ('36658', datetime.datetime(2024, 11, 20, 0, 0)),
#  ('36659', datetime.datetime(2024, 11, 20, 0, 0)),
#  ('35475', datetime.datetime(2024, 11, 19, 0, 0)),
#  ('36333', datetime.datetime(2024, 11, 19, 0, 0)),
#  ('34158-(R2048)', datetime.datetime(2024, 11, 18, 0, 0)),
#  ('33192', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('35604', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('34054', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('36653', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('36654', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('36656', datetime.datetime(2024, 11, 15, 0, 0)),
#  ('31731', datetime.datetime(2024, 11, 14, 0, 0)),
#  ('23686', datetime.datetime(2024, 11, 14, 0, 0)),
#  ('34340', datetime.datetime(2024, 11, 13, 0, 0)),
#  ('36433', datetime.datetime(2024, 11, 13, 0, 0)),
#  ('36462', datetime.datetime(2024, 11, 13, 0, 0)),
#  ('36599', datetime.datetime(2024, 11, 13, 0, 0)),
#  ('36652', datetime.datetime(2024, 11, 13, 0, 0)),
#  ('31016', datetime.datetime(2024, 11, 12, 0, 0)),
#  ('30371', datetime.datetime(2024, 11, 12, 0, 0)),
#  ('33846', datetime.datetime(2024, 11, 12, 0, 0)),
#  ('36621', datetime.datetime(2024, 11, 12, 0, 0)),
#  ('28828', datetime.datetime(2024, 11, 11, 0, 0)),
#  ('32163', datetime.datetime(2024, 11, 11, 0, 0)),
#  ('17050', datetime.datetime(2024, 11, 6, 0, 0)),
#  ('26447', datetime.datetime(2024, 11, 6, 0, 0)),
#  ('30669', datetime.datetime(2024, 11, 6, 0, 0)),
#  ('29214', datetime.datetime(2024, 11, 6, 0, 0)),
#  ('36650', datetime.datetime(2024, 11, 6, 0, 0)),
#  ('31789', datetime.datetime(2024, 11, 5, 0, 0)),
#  ('31388', datetime.datetime(2024, 11, 5, 0, 0)),
#  ('36343', datetime.datetime(2024, 11, 5, 0, 0)),
#  ('36613-L', datetime.datetime(2024, 11, 1, 0, 0)),
#  ('36613-XIII', datetime.datetime(2024, 11, 1, 0, 0)),
#  ('36613-IV', datetime.datetime(2024, 10, 31, 0, 0)),
#  ('36613-XIV', datetime.datetime(2024, 10, 31, 0, 0)),
#  ('36613-XVI', datetime.datetime(2024, 10, 31, 0, 0)),
#  ('36646-(R2203)', datetime.datetime(2024, 10, 31, 0, 0)),
#  ('36194', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36544', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-A', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-B', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-C', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-I', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-IIA', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-IIB', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-III', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-IX', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-J', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-K', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-V', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-VI', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-VII', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-VIII', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-X', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-XII', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-XV', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36613-XVII', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36645', datetime.datetime(2024, 10, 30, 0, 0)),
#  ('36456', datetime.datetime(2024, 10, 25, 0, 0)),
#  ('34765', datetime.datetime(2024, 10, 24, 0, 0)),
#  ('36642', datetime.datetime(2024, 10, 24, 0, 0)),
#  ('26419', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('30635', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('33340', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('32026-(R1888)', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('34269', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('33845', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('36637', datetime.datetime(2024, 10, 22, 0, 0)),
#  ('29452', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('30995', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('34359', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('35917', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('34463', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('35529', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('36390', datetime.datetime(2024, 10, 21, 0, 0)),
#  ('19291', datetime.datetime(2024, 10, 18, 0, 0)),
#  ('36494', datetime.datetime(2024, 10, 18, 0, 0)),
#  ('24036', datetime.datetime(2024, 10, 17, 0, 0)),
#  ('36455-(R2188)', datetime.datetime(2024, 10, 17, 0, 0)),
#  ('36534-(R2193)', datetime.datetime(2024, 10, 17, 0, 0)),
#  ('34300', datetime.datetime(2024, 10, 16, 0, 0)),
#  ('36451', datetime.datetime(2024, 10, 16, 0, 0)),
#  ('33670', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36417', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36629', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36630', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36631-(R2199)', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36632-(R2200)', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('36633', datetime.datetime(2024, 10, 15, 0, 0)),
#  ('33173', datetime.datetime(2024, 10, 14, 0, 0)),
#  ('35079', datetime.datetime(2024, 10, 11, 0, 0)),
#  ('36241', datetime.datetime(2024, 10, 11, 0, 0)),
#  ('36275', datetime.datetime(2024, 10, 11, 0, 0)),
#  ('36479', datetime.datetime(2024, 10, 11, 0, 0)),
#  ('CLVI', datetime.datetime(2024, 10, 11, 0, 0)),
#  ('34568', datetime.datetime(2024, 10, 10, 0, 0)),
#  ('30982', datetime.datetime(2024, 10, 9, 0, 0)),
#  ('32646', datetime.datetime(2024, 10, 9, 0, 0)),
#  ('36587-(R2197)', datetime.datetime(2024, 10, 9, 0, 0)),
#  ('36627', datetime.datetime(2024, 10, 9, 0, 0)),
#  ('36628', datetime.datetime(2024, 10, 9, 0, 0)),
#  ('32800', datetime.datetime(2024, 10, 7, 0, 0)),
#  ('36145', datetime.datetime(2024, 10, 7, 0, 0)),
#  ('36586', datetime.datetime(2024, 10, 4, 0, 0)),
#  ('29435', datetime.datetime(2024, 10, 3, 0, 0)),
#  ('32201', datetime.datetime(2024, 10, 3, 0, 0)),
#  ('29842', datetime.datetime(2024, 10, 3, 0, 0)),
#  ('36585', datetime.datetime(2024, 10, 3, 0, 0)),
#  ('36364', datetime.datetime(2024, 10, 2, 0, 0)),
#  ('36622', datetime.datetime(2024, 10, 2, 0, 0)),
#  ('36623', datetime.datetime(2024, 10, 2, 0, 0)),
#  ('29385', datetime.datetime(2024, 10, 1, 0, 0)),
#  ('31570', datetime.datetime(2024, 10, 1, 0, 0)),
#  ('36264', datetime.datetime(2024, 10, 1, 0, 0)),
#  ('36503', datetime.datetime(2024, 10, 1, 0, 0)),
#  ('36620', datetime.datetime(2024, 10, 1, 0, 0)),
#  ('35619', datetime.datetime(2024, 9, 27, 0, 0)),
#  ('35621', datetime.datetime(2024, 9, 27, 0, 0)),
#  ('25834', datetime.datetime(2024, 9, 26, 0, 0)),
#  ('36027-(R2160)', datetime.datetime(2024, 9, 26, 0, 0)),
#  ('36028', datetime.datetime(2024, 9, 26, 0, 0)),
#  ('36410-A', datetime.datetime(2024, 9, 26, 0, 0)),
#  ('36530', datetime.datetime(2024, 9, 26, 0, 0)),
#  ('31104', datetime.datetime(2024, 9, 25, 0, 0)),
#  ('33650', datetime.datetime(2024, 9, 25, 0, 0)),
#  ('36124', datetime.datetime(2024, 9, 25, 0, 0)),
#  ('34878', datetime.datetime(2024, 9, 25, 0, 0)),
#  ('36506', datetime.datetime(2024, 9, 25, 0, 0)),
#  ('35433', datetime.datetime(2024, 9, 24, 0, 0)),
#  ('36619', datetime.datetime(2024, 9, 24, 0, 0)),
#  ('35603', datetime.datetime(2024, 9, 20, 0, 0)),
#  ('36350', datetime.datetime(2024, 9, 20, 0, 0)),
#  ('36528', datetime.datetime(2024, 9, 19, 0, 0)),
#  ('32012', datetime.datetime(2024, 9, 17, 0, 0)),
#  ('36410-IV', datetime.datetime(2024, 9, 17, 0, 0)),
#  ('34124', datetime.datetime(2024, 9, 16, 0, 0)),
#  ('36410-VI', datetime.datetime(2024, 9, 16, 0, 0)),
#  ('36410-VIII', datetime.datetime(2024, 9, 16, 0, 0)),
#  ('36593', datetime.datetime(2024, 9, 16, 0, 0)),
#  ('36560-A', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-B', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-C', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-I', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-IIA', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-IIB', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-III', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-IX', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-J', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-K', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-L', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-V', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-VI', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-VII', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-XIII', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-VIII', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-X', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-XII', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-XV', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-XVI', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36560-XVII', datetime.datetime(2024, 9, 13, 0, 0)),
#  ('36410-IX', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('36473', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('36560-IV', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('36560-XIV', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('36595', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('36596', datetime.datetime(2024, 9, 12, 0, 0)),
#  ('30180', datetime.datetime(2024, 9, 11, 0, 0)),
#  ('35555', datetime.datetime(2024, 9, 11, 0, 0)),
#  ('36518', datetime.datetime(2024, 9, 11, 0, 0)),
#  ('36403', datetime.datetime(2024, 9, 10, 0, 0)),
#  ('33104', datetime.datetime(2024, 9, 9, 0, 0)),
#  ('32173', datetime.datetime(2024, 9, 6, 0, 0)),
#  ('34580', datetime.datetime(2024, 9, 5, 0, 0)),
#  ('36538', datetime.datetime(2024, 9, 5, 0, 0)),
#  ('36539', datetime.datetime(2024, 9, 5, 0, 0)),
#  ('36136', datetime.datetime(2024, 9, 3, 0, 0)),
#  ('36257', datetime.datetime(2024, 9, 3, 0, 0)),
#  ('36285', datetime.datetime(2024, 9, 3, 0, 0)),
#  ('36532', datetime.datetime(2024, 9, 3, 0, 0)),
#  ('36550-L', datetime.datetime(2024, 9, 2, 0, 0)),
#  ('36550-XIII', datetime.datetime(2024, 9, 2, 0, 0)),
#  ('36550-XVI', datetime.datetime(2024, 9, 2, 0, 0)),
#  ('36591', datetime.datetime(2024, 9, 2, 0, 0)),
#  ('28140', datetime.datetime(2024, 8, 30, 0, 0)),
#  ('36197', datetime.datetime(2024, 8, 28, 0, 0)),
#  ('36410-XVI', datetime.datetime(2024, 8, 21, 0, 0)),
#  ('36410-C', datetime.datetime(2024, 8, 20, 0, 0)),
#  ('31109', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('35154', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('35761', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('36408', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('36484', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('36550-IX', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('36550-VIII', datetime.datetime(2024, 8, 19, 0, 0)),
#  ('34919', datetime.datetime(2024, 7, 29, 0, 0)),
#  ('36442', datetime.datetime(2024, 7, 29, 0, 0)),
#  ('29539', datetime.datetime(2024, 7, 25, 0, 0)),
#  ('36203', datetime.datetime(2024, 7, 24, 0, 0)),
#  ('35626', datetime.datetime(2024, 7, 24, 0, 0)),
#  ('32851', datetime.datetime(2024, 7, 19, 0, 0)),
#  ('30490', datetime.datetime(2024, 7, 19, 0, 0)),
#  ('36380', datetime.datetime(2024, 7, 19, 0, 0)),
#  ('36410-X', datetime.datetime(2024, 7, 18, 0, 0)),
#  ('36410-L', datetime.datetime(2024, 7, 17, 0, 0)),
#  ('36589', datetime.datetime(2024, 7, 17, 0, 0)),
#  ('36550-XIV', datetime.datetime(2024, 7, 16, 0, 0)),
#  ('27157', datetime.datetime(2024, 7, 15, 0, 0)),
#  ('34338', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('33283', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('35578', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('35930', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('36272', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('36377', datetime.datetime(2024, 7, 12, 0, 0)),
#  ('36550-B', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-C', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-I', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-IIA', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-IIB', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-III', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-IV', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-K', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-V', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-X', datetime.datetime(2024, 7, 9, 0, 0)),
#  ('36550-A', datetime.datetime(2024, 7, 8, 0, 0)),
#  ('36550-J', datetime.datetime(2024, 7, 8, 0, 0)),
#  ('36550-XII', datetime.datetime(2024, 7, 8, 0, 0)),
#  ('36558', datetime.datetime(2024, 7, 8, 0, 0)),
#  ('36054', datetime.datetime(2024, 7, 5, 0, 0)),
#  ('36550', datetime.datetime(2024, 7, 5, 0, 0)),
#  ('35992', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('36321-(R2181)', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('36550-VII', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('36550-XV', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('36550-XVII', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('CLIX', datetime.datetime(2024, 7, 4, 0, 0)),
#  ('27062', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('29507', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('33033', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('31125', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('36036', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('36178', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('36491', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('36550-VI', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('36560', datetime.datetime(2024, 7, 3, 0, 0)),
#  ('23235', datetime.datetime(2024, 7, 2, 0, 0)),
#  ('34763', datetime.datetime(2024, 7, 2, 0, 0)),
#  ('32855', datetime.datetime(2024, 7, 1, 0, 0)),
#  ('36580', datetime.datetime(2024, 7, 1, 0, 0)),
#  ('36375', datetime.datetime(2024, 6, 28, 0, 0)),
#  ('31478', datetime.datetime(2024, 6, 27, 0, 0)),
#  ('36410-XVII', datetime.datetime(2024, 6, 27, 0, 0)),
#  ('36410-XV', datetime.datetime(2024, 6, 27, 0, 0)),
#  ('36434', datetime.datetime(2024, 6, 27, 0, 0)),
#  ('36317', datetime.datetime(2024, 6, 25, 0, 0)),
#  ('36217', datetime.datetime(2024, 6, 25, 0, 0)),
#  ('32715', datetime.datetime(2024, 6, 24, 0, 0)),
#  ('29528', datetime.datetime(2024, 6, 24, 0, 0)),
#  ('34767', datetime.datetime(2024, 6, 24, 0, 0)),
#  ('35844', datetime.datetime(2024, 6, 24, 0, 0)),
#  ('36508', datetime.datetime(2024, 6, 21, 0, 0)),
#  ('34424', datetime.datetime(2024, 6, 21, 0, 0)),
#  ('36270', datetime.datetime(2024, 6, 21, 0, 0)),
#  ('36554', datetime.datetime(2024, 6, 21, 0, 0)),
#  ('24493-(R1557)', datetime.datetime(2024, 6, 20, 0, 0)),
#  ('36171', datetime.datetime(2024, 6, 20, 0, 0)),
#  ('36461', datetime.datetime(2024, 6, 20, 0, 0)),
#  ('34372', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('29659', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('34349', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('35870', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('36351-(R2184)', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('36453', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('36515', datetime.datetime(2024, 6, 19, 0, 0)),
#  ('31036', datetime.datetime(2024, 6, 18, 0, 0)),
#  ('33566', datetime.datetime(2024, 6, 18, 0, 0)),
#  ('36310', datetime.datetime(2024, 6, 18, 0, 0)),
#  ('36386', datetime.datetime(2024, 6, 18, 0, 0)),
#  ('24490', datetime.datetime(2024, 6, 17, 0, 0)),
#  ('35351', datetime.datetime(2024, 6, 17, 0, 0)),
#  ('36195', datetime.datetime(2024, 6, 17, 0, 0)),
#  ('36570', datetime.datetime(2024, 6, 17, 0, 0)),
#  ('36572', datetime.datetime(2024, 6, 17, 0, 0)),
#  ('36492', datetime.datetime(2024, 6, 14, 0, 0)),
#  ('36573-(R2196)', datetime.datetime(2024, 6, 14, 0, 0)),
#  ('30985', datetime.datetime(2024, 6, 13, 0, 0)),
#  ('35896', datetime.datetime(2024, 6, 13, 0, 0)),
#  ('36411', datetime.datetime(2024, 6, 13, 0, 0)),
#  ('36463', datetime.datetime(2024, 6, 13, 0, 0)),
#  ('25074', datetime.datetime(2024, 6, 12, 0, 0)),
#  ('35826', datetime.datetime(2024, 6, 12, 0, 0)),
#  ('36389', datetime.datetime(2024, 6, 12, 0, 0)),
#  ('36504', datetime.datetime(2024, 6, 12, 0, 0)),
#  ('36568', datetime.datetime(2024, 6, 12, 0, 0)),
#  ('35982', datetime.datetime(2024, 6, 11, 0, 0)),
#  ('36259', datetime.datetime(2024, 6, 11, 0, 0)),
#  ('36360-XII', datetime.datetime(2024, 6, 11, 0, 0)),
#  ('36540', datetime.datetime(2024, 6, 10, 0, 0)),
#  ('36567', datetime.datetime(2024, 6, 10, 0, 0)),
#  ('36543', datetime.datetime(2024, 6, 7, 0, 0)),
#  ('36553-(R2195)', datetime.datetime(2024, 6, 7, 0, 0)),
#  ('29248', datetime.datetime(2024, 6, 6, 0, 0)),
#  ('36202', datetime.datetime(2024, 6, 6, 0, 0)),
#  ('32402', datetime.datetime(2024, 6, 6, 0, 0)),
#  ('36482', datetime.datetime(2024, 6, 6, 0, 0)),
#  ('34891', datetime.datetime(2024, 6, 5, 0, 0)),
#  ('36564', datetime.datetime(2024, 6, 5, 0, 0)),
#  ('33992-(R2034)', datetime.datetime(2024, 6, 4, 0, 0)),
#  ('36510', datetime.datetime(2024, 5, 31, 0, 0)),
#  ('30862', datetime.datetime(2024, 5, 30, 0, 0)),
#  ('30512', datetime.datetime(2024, 5, 30, 0, 0)),
#  ('31787', datetime.datetime(2024, 5, 29, 0, 0)),
#  ('36210', datetime.datetime(2024, 5, 29, 0, 0)),
#  ('36469', datetime.datetime(2024, 5, 29, 0, 0)),
#  ('36562', datetime.datetime(2024, 5, 29, 0, 0)),
#  ('36569', datetime.datetime(2024, 5, 29, 0, 0)),
#  ('29447', datetime.datetime(2024, 5, 28, 0, 0)),
#  ('36559', datetime.datetime(2024, 5, 28, 0, 0)),
#  ('29818', datetime.datetime(2024, 5, 24, 0, 0)),
#  ('34985', datetime.datetime(2024, 5, 24, 0, 0)),
#  ('33797', datetime.datetime(2024, 5, 24, 0, 0)),
#  ('35883', datetime.datetime(2024, 5, 24, 0, 0)),
#  ('35373', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('36421', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('33587', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('33707', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('33703', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('33769', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('34298', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('34995', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('34661', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('34698', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('35105', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('35157', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('35410', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('35809-(R2152)', datetime.datetime(2024, 5, 23, 0, 0)),
#  ('35034', datetime.datetime(2024, 5, 22, 0, 0)),
#  ('36128', datetime.datetime(2024, 5, 22, 0, 0)),
#  ('36410-IIB', datetime.datetime(2024, 5, 22, 0, 0)),
#  ('36525', datetime.datetime(2024, 5, 22, 0, 0)),
#  ('36353-(R2185)', datetime.datetime(2024, 5, 21, 0, 0)),
#  ('33296', datetime.datetime(2024, 5, 17, 0, 0)),
#  ('36487', datetime.datetime(2024, 5, 17, 0, 0)),
#  ('35282', datetime.datetime(2024, 5, 17, 0, 0)),
#  ('35714', datetime.datetime(2024, 5, 17, 0, 0)),
#  ('33189', datetime.datetime(2024, 5, 16, 0, 0)),
#  ('35825', datetime.datetime(2024, 5, 16, 0, 0)),
#  ('36556', datetime.datetime(2024, 5, 16, 0, 0)),
#  ...]

# %%
# build a list of identifiers; we will pick out the documents later
chosen_dossiers = []  

total_size = 0
for dossier_id, _ in dossier_maxdate:
    dossier_size = sum( dossier_bytesizes[dossier_id] )
    chosen_dossiers.append( dossier_id )
    print("Chose dossier  %-15r  (%5d docs totaling %5s)"%(dossier_id, len(dossier_bytesizes[dossier_id]), wetsuite.helpers.format.kmgtp(dossier_size)))
    total_size += dossier_size

    # Once we selected a bunch of data, we can stop selecting
    if total_size > 700*1024*1024: # 700MB
        break

print('Chose %s (%5s) out of %s dossiers'%(len(chosen_dossiers), wetsuite.helpers.format.kmgtp(total_size), len(dossier_maxdate)))
# Out:
# Chose dossier  '31839'          ( 1183 docs totaling   25M)
# Chose dossier  '25295'          ( 2944 docs totaling   56M)
# Chose dossier  '31066'          ( 1593 docs totaling   40M)
# Chose dossier  '21501-08'       ( 1039 docs totaling   21M)
# Chose dossier  '33037'          (  659 docs totaling 12.4M)
# Chose dossier  '30252'          (  225 docs totaling  3.4M)
# Chose dossier  '32140'          (  280 docs totaling 10.6M)
# Chose dossier  '36546'          (   41 docs totaling  2.2M)
# Chose dossier  '32847'          ( 1412 docs totaling   29M)
# Chose dossier  '28676'          (  528 docs totaling 13.8M)
# Chose dossier  '21501-28'       (  288 docs totaling  8.5M)
# Chose dossier  '34293'          (  158 docs totaling  3.1M)
# Chose dossier  '36600-VIII'     (  190 docs totaling  9.4M)
# Chose dossier  '36626'          (    8 docs totaling  488K)
# Chose dossier  '27625'          (  798 docs totaling 12.3M)
# Chose dossier  '29237'          (  228 docs totaling  5.1M)
# Chose dossier  '24587'          ( 1245 docs totaling   19M)
# Chose dossier  '32317'          ( 1397 docs totaling   45M)
# Chose dossier  '22112'          ( 4485 docs totaling  123M)
# Chose dossier  '21501-20'       ( 2507 docs totaling   27M)
# Chose dossier  '22026'          (  584 docs totaling 12.1M)
# Chose dossier  '27020'          (  140 docs totaling  4.2M)
# Chose dossier  '27925'          ( 1119 docs totaling   34M)
# Chose dossier  '33576'          (  527 docs totaling  9.6M)
# Chose dossier  '21501-07'       ( 2289 docs totaling   68M)
# Chose dossier  '21501-31'       (  901 docs totaling   23M)
# Chose dossier  '32813'          ( 1739 docs totaling   34M)
# Chose dossier  '29023'          (  641 docs totaling 13.2M)
# Chose dossier  '35334'          (  572 docs totaling 12.8M)
# Chose dossier  '32637'          (  767 docs totaling   18M)
# Chose dossier  '27565'          (  217 docs totaling  3.5M)
# Chose dossier  '29362'          (  536 docs totaling  8.7M)
# Chose dossier  '31293'          (  860 docs totaling   21M)
# Chose dossier  '29665'          (  683 docs totaling  8.1M)
# Chose 34 ( 737M) out of 14398 dossiers

# %% [markdown]
# #### h (handelingen) and ah (their aanhangsels )
#
# Okay, we've dealt with `kst`. What about these two, and their relation?
#
# So, from the counting code below, there seem to be:
# * ~56K `h-` documents totaling 2.2GByte of XML
# * ~84K `ah-`documents totaling 700MByte of XML
# * if restricting that to 5 years:
#   * ~14K `h-` documents totaling 600MByte of XML
#   * ~18K `ah-`documents totaling 200Byte of XML
#
# We _could_ consider just including **all** of both these sets,
# that way we don't have to worry yet about fishing out all required relations, different types of handelingen, etc.

# %%
h_amount,  total_h_size = 0, 0
ah_amount, total_ah_size = 0, 0

hah_chosen_ids = set()

# go through all identifiers's metadata, decide what to select
# roughly speaking: 
for doc_id in id_meta.keys(): 
    
    meta = id_meta[doc_id]

    # note: not used yet; only used in combination
    meta_date = wetsuite.helpers.date.parse( meta['available'] )
    is_old = False 
    if meta_date.date() < wetsuite.helpers.date.date_months_ago( 12*5 ): # not in last 5 years?
        is_old = True

    if doc_id.startswith('ah-'): 
        # anything from the last five years
        if is_old:
            continue
        ah_amount += 1
        total_ah_size += len(op_fetched.get( id_xmlurl[doc_id] ))
        hah_chosen_ids.add(doc_id)
        continue

    elif doc_id.startswith('h-'):
        # h(andelingen) may refer to kamerstukdossiers. While we could skip these,
        #   yet let's try to select them even if they are older _if_ they seem to refer to a dossier we selected.
        # So our logic becomes 'anything from the last five years  OR  referring to a dossier we selected'
        refers_to_chosen_kst = False
        if 'behandeldDossier' in meta:
            behandeldDossier = meta['behandeldDossier'].split(';')[0] # split because it points to a specific number in that dossier
            if behandeldDossier in chosen_dossiers:
                refers_to_chosen_kst = True

        if is_old and not refers_to_chosen_kst:
            continue
        else:
            h_amount += 1
            total_h_size += len(op_fetched.get( id_xmlurl[doc_id] ))
            hah_chosen_ids.add(doc_id)
            continue

    # implied else: type is kst or other

h_amount, total_h_size,  ah_amount, total_ah_size
# Out:
# (13410, 601661806, 18206, 217210592)

# %% [markdown]
# ### Finally write it out

# %%
import wetsuite.datasets
op_selection = wetsuite.helpers.localdata.LocalKV( 'parliament-sample.db', str, bytes )
op_selection.truncate()

op_selection._put_meta('description_short', 'A moderate-sized collection of kamerstukken, handelingen, and aanhangsels')
op_selection._put_meta('description','''
                       
A moderate-sized collection of kamerstukken (~700MB of the most recently touched dossiers), handelingen (up to five years), and aanhangsels (up to five years)
                       
For each conceptual item, e.g. kst-27625-351, it contains
- a metadata XML, e.g. https://repository.overheid.nl/frbr/officielepublicaties/kst/27625/kst-27625-351/1/metadata/metadata.xml
- an content XML, e.g. https://repository.overheid.nl/frbr/officielepublicaties/kst/27625/kst-27625-351/1/xml/kst-27625-351.xml                       

The metadata file can be parsed with wetsuite.helpers.koop_parse.parse_op_metafile()

TODO: more elaboration
                                              
Dataset generated on:                        
'''+wetsuite.datasets.generated_today_text())

# %%
# adding kst- (chosen subset)
for dossier_id in chosen_dossiers:
    for doc_id in dossier_doc_ids[ dossier_id ]:
        xml_url  = id_xmlurl[doc_id]
        meta_url = docmeta_groups[doc_id]['metadata']
        op_selection.put( xml_url,  op_fetched.get( xml_url ) , commit=False )
        op_selection.put( meta_url, op_fetched.get( meta_url ), commit=False )
        #print( xml_url, meta_url )
        #break
    #break

op_selection.commit()

op_selection.summary( True )
# Out:
# {'size_bytes': 880533504,
#  'size_readable': '840MiB',
#  'num_items': 64698,
#  'avgsize_bytes': 13610,
#  'avgsize_readable': '13.3KiB'}

# %%
# adding h- ahd ah- (chosen subset)
for doc_id in hah_chosen_ids:
    xml_url  = id_xmlurl[doc_id]
    meta_url = docmeta_groups[doc_id]['metadata']
    op_selection.put( xml_url,  op_fetched.get( xml_url ),     commit=False)
    op_selection.put( meta_url, op_fetched.get( meta_url ),    commit=False)

op_selection.commit()
op_selection.summary( True )
# Out:
# {'size_bytes': 1846579200,
#  'size_readable': '1.7GiB',
#  'num_items': 127930,
#  'avgsize_bytes': 14434,
#  'avgsize_readable': '14.1KiB'}

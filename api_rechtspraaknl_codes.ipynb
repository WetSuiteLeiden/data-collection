# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/data-collection/blob/master/api_rechtspraaknl_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source. 
#    (this should soon simplify to something like   !pip3 install --upgrade wetsuite)
# For your own setup, see wetsuite's install guidelines.
# !pip3 install -U --no-cache-dir --quiet https://github.com/WetSuiteLeiden/wetsuite-core/archive/refs/heads/main.zip

# %% [markdown]
# # Purpose of this notebook
#
# Getting some value lists out of [rechtspraak.nl](https://www.rechtspraak.nl/),
# in part for wordlist-like use, in part for use in search queries.
#
# For example, there is a list of categories at https://data.rechtspraak.nl/Waardelijst/Rechtsgebieden
#
# The strings and codes might potentially be things to search for, and/or find in metadata,
# or to provide a list of as context, so we would like this in data form.

# %% [markdown]
# ## Values for filters
#
# ### Rechtsgebieden

# %%
import wetsuite.datacollect.rechtspraaknl

rgb = wetsuite.datacollect.rechtspraaknl.parse_rechtsgebieden() # fetches and parses

# rgb is a dict, from identifiers to a list of names, which will e.g. contain 
#     'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht':                   ['Bestuursrecht']
# as well as
#     'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_mededingingsrecht': ['Mededingingsrecht', 'Bestuursrecht']

# Meaning Bestuursrecht is a grouping of this and more, and Mededingingsrecht one of several specific parts of Bestuursrecht

# %% [markdown]
# the shape of the data above might do for just lookups of such identifiers.
#
# If you wanted to present it as grouped / tree-like categories, you would need some slightly awkward code.
# Said code might look like:

# %%
# For that purpose, a little restructuring is useful
rechtsgebieden_groups = {}
for identifier, namelist in rgb.items():
    if len(namelist)==1:
        broad, = namelist
        rechtsgebieden_groups[broad] = {'identifier':identifier, 'name':broad, 'specific':[]}
    elif len(namelist)==2:
        specific, broad = namelist
        rechtsgebieden_groups[broad]['specific'].append( {'identifier':identifier, 'name':specific} )

# %%
# such data looks something like (subset)
list(rechtsgebieden_groups.items())[0]
# Out:
# ('Bestuursrecht',
#  {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht',
#   'name': 'Bestuursrecht',
#   'specific': [{'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_ambtenarenrecht',
#     'name': 'Ambtenarenrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_belastingrecht',
#     'name': 'Belastingrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_bestuursprocesrecht',
#     'name': 'Bestuursprocesrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_bestuursstrafrecht',
#     'name': 'Bestuursstrafrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_europeesBestuursrecht',
#     'name': 'Europees bestuursrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_mededingingsrecht',
#     'name': 'Mededingingsrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_omgevingsrecht',
#     'name': 'Omgevingsrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_socialezekerheidsrecht',
#     'name': 'Socialezekerheidsrecht'},
#    {'identifier': 'http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_vreemdelingenrecht',
#     'name': 'Vreemdelingenrecht'}]})

# %%
# which you might use something like:

for groupkey, groupdetails in rechtsgebieden_groups.items():
    print( '%-30s      (%s)'%(groupdetails['name'], groupdetails['identifier']) )
    for subgroup in groupdetails['specific']:
        print( '    %-30s  (%s)'%(subgroup['name'], subgroup['identifier']) )
# Out:
# Bestuursrecht                       (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht)
#     Ambtenarenrecht                 (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_ambtenarenrecht)
#     Belastingrecht                  (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_belastingrecht)
#     Bestuursprocesrecht             (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_bestuursprocesrecht)
#     Bestuursstrafrecht              (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_bestuursstrafrecht)
#     Europees bestuursrecht          (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_europeesBestuursrecht)
#     Mededingingsrecht               (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_mededingingsrecht)
#     Omgevingsrecht                  (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_omgevingsrecht)
#     Socialezekerheidsrecht          (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_socialezekerheidsrecht)
#     Vreemdelingenrecht              (http://psi.rechtspraak.nl/rechtsgebied#bestuursrecht_vreemdelingenrecht)
# Civiel recht                        (http://psi.rechtspraak.nl/rechtsgebied#civielRecht)
#     Aanbestedingsrecht              (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_aanbestedingsrecht)
#     Arbeidsrecht                    (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_arbeidsrecht)
#     Burgerlijk procesrecht          (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_burgerlijkProcesrecht)
#     Europees civiel recht           (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_europeesCivielRecht)
#     Goederenrecht                   (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_goederenrecht)
#     Insolventierecht                (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_insolventierecht)
#     Intellectueel-eigendomsrecht    (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_intellectueeleigendomsrecht)
#     Internationaal privaatrecht     (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_internationaalPrivaatrecht)
#     Mededingingsrecht               (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_mededingingsrecht)
#     Ondernemingsrecht               (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_ondernemingsrecht)
#     Personen- en familierecht       (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_personenEnFamilierecht)
#     Verbintenissenrecht             (http://psi.rechtspraak.nl/rechtsgebied#civielRecht_verbintenissenrecht)
# Strafrecht                          (http://psi.rechtspraak.nl/rechtsgebied#strafrecht)
#     Europees strafrecht             (http://psi.rechtspraak.nl/rechtsgebied#strafrecht_europeesStrafrecht)
#     Internationaal strafrecht       (http://psi.rechtspraak.nl/rechtsgebied#strafrecht_internationaalStrafrecht)
#     Materieel strafrecht            (http://psi.rechtspraak.nl/rechtsgebied#strafrecht_materieelStrafrecht)
#     Penitentiair strafrecht         (http://psi.rechtspraak.nl/rechtsgebied#strafrecht_penitentiairStrafrecht)
#     Strafprocesrecht                (http://psi.rechtspraak.nl/rechtsgebied#strafrecht_strafprocesrecht)
# Internationaal publiekrecht         (http://psi.rechtspraak.nl/rechtsgebied#internationaalPubliekrecht)
#     Mensenrechten                   (http://psi.rechtspraak.nl/rechtsgebied#internationaalPubliekrecht_mensenrechten)
#     Volkenrecht                     (http://psi.rechtspraak.nl/rechtsgebied#internationaalPubliekrecht_volkenrecht)

# %% [markdown]
# ### Instanties

# %%
# basically fetch https://data.rechtspraak.nl/Waardelijst/Instanties into data
import wetsuite.datacollect.rechtspraaknl
wetsuite.datacollect.rechtspraaknl.parse_instanties()
# Out:
# [{'Identifier': 'http://psi.rechtspraak.nl/AG DH',
#   'Naam': "Ambtenarengerecht 's-Gravenhage",
#   'Afkorting': 'AGSGR',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agdb',
#   'Naam': "Ambtenarengerecht 's-Hertogenbosch",
#   'Afkorting': 'AGSHE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agam',
#   'Naam': 'Ambtenarengerecht Amsterdam',
#   'Afkorting': 'AGAMS',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agah',
#   'Naam': 'Ambtenarengerecht Arnhem',
#   'Afkorting': 'AGARN',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/aggr',
#   'Naam': 'Ambtenarengerecht Groningen',
#   'Afkorting': 'AGGRO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/aghl',
#   'Naam': 'Ambtenarengerecht Haarlem',
#   'Afkorting': 'AGHAA',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agrm',
#   'Naam': 'Ambtenarengerecht Roermond',
#   'Afkorting': 'AGROE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agrd',
#   'Naam': 'Ambtenarengerecht Rotterdam',
#   'Afkorting': 'AGROT',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agut',
#   'Naam': 'Ambtenarengerecht Utrecht',
#   'Afkorting': 'AGUTR',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/agzw',
#   'Naam': 'Ambtenarengerecht Zwolle',
#   'Afkorting': 'AGZWO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/ArrKR Arn',
#   'Naam': 'Arrondissementskrijgsraad Arnhem',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#BijzonderHofsGravenhage',
#   'Naam': "Bijzonder Hof 's-Gravenhage",
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#BijzonderHofAmsterdam',
#   'Naam': 'Bijzonder Hof Amsterdam',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#BijzonderHofArnhem',
#   'Naam': 'Bijzonder Hof Arnhem',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#BijzondereRaadvanCassatie',
#   'Naam': 'Bijzondere Raad van Cassatie',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/CvBStuf',
#   'Naam': 'College van Beroep Studiefinanciering',
#   'Afkorting': 'CVBSTUF',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2000-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/cvbhb',
#   'Naam': 'College van Beroep voor het hoger onderwijs',
#   'Afkorting': 'CBHO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2022-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#HMGNederlandsIndië',
#   'Naam': 'HMG Nederlands-Indië',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/HMG',
#   'Naam': 'Hoog Militair Gerechtshof',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1991-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#HooggerechtshofBatavia',
#   'Naam': 'Hooggerechtshof Batavia',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#Krijgsraad',
#   'Naam': 'Krijgsraad',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#KrijgsraadArnhem',
#   'Naam': 'Krijgsraad Arnhem',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/PKvdZSgr',
#   'Naam': "Permanente Krijgsraad voor de zeemacht 's-Gravenhage",
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1971-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/PKvdZmAA',
#   'Naam': 'Permanente Krijgsraad voor de zeemacht N.A. en Aruba',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1971-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvAvdB',
#   'Naam': 'Raad van Arbitrage in Bouwgeschillen',
#   'Afkorting': 'RVAB',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBSgr',
#   'Naam': "Raad van beroep 's-Gravenhage",
#   'Afkorting': 'RVBSGR',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBShe',
#   'Naam': "Raad van beroep 's-Hertogenbosch",
#   'Afkorting': 'RVBSHE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBAm',
#   'Naam': 'Raad van beroep Alkmaar',
#   'Afkorting': 'RVBALK',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBAms',
#   'Naam': 'Raad van beroep Amsterdam',
#   'Afkorting': 'RVBAMS',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBArn',
#   'Naam': 'Raad van beroep Arnhem',
#   'Afkorting': 'RVBARN',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBb',
#   'Naam': 'Raad van beroep Breda',
#   'Afkorting': 'RVBBRE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBGro',
#   'Naam': 'Raad van beroep Groningen',
#   'Afkorting': 'RVBGRO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBHaa',
#   'Naam': 'Raad van beroep Haarlem',
#   'Afkorting': 'RVBHAA',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBLe',
#   'Naam': 'Raad van beroep Leeuwarden',
#   'Afkorting': 'RVBLEE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/rvbl',
#   'Naam': 'Raad van beroep Leiden',
#   'Afkorting': 'RVBLDN',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBM',
#   'Naam': 'Raad van beroep Middelburg',
#   'Afkorting': 'RVBMID',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBRoe',
#   'Naam': 'Raad van beroep Roermond',
#   'Afkorting': 'RVBROE',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBRot',
#   'Naam': 'Raad van beroep Rotterdam',
#   'Afkorting': 'RVBROT',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBT',
#   'Naam': 'Raad van beroep Tilburg',
#   'Afkorting': 'RVBTIL',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBUtr',
#   'Naam': 'Raad van beroep Utrecht',
#   'Afkorting': 'RVBUTR',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBZwo',
#   'Naam': 'Raad van beroep Zwolle',
#   'Afkorting': 'RVBZWO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1992-07-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/BCRSTJ',
#   'Naam': 'Raad voor Strafrechtstoepassing en Jeugdbescherming',
#   'Afkorting': 'RSJ',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/AndereGerechtelijkeInstantie/#RbHollandia',
#   'Naam': 'Rb. Hollandia',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/TariefCommissie',
#   'Naam': 'Tariefcommissie',
#   'Afkorting': 'DETARCO',
#   'Type': 'AndereGerechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': "http://standaarden.overheid.nl/owms/terms/Gerechtshof_'s-Gravenhage",
#   'Naam': "Gerechtshof 's-Gravenhage",
#   'Afkorting': 'GHSGR',
#   'Type': 'Gerechtshof',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': "http://standaarden.overheid.nl/owms/terms/Gerechtshof_'s-Hertogenbosch",
#   'Naam': "Gerechtshof 's-Hertogenbosch",
#   'Afkorting': 'GHSHE',
#   'Type': 'Gerechtshof',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerechtshof_Amsterdam',
#   'Naam': 'Gerechtshof Amsterdam',
#   'Afkorting': 'GHAMS',
#   'Type': 'Gerechtshof',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerechtshof_Arnhem',
#   'Naam': 'Gerechtshof Arnhem',
#   'Afkorting': 'GHARN',
#   'Type': 'Gerechtshof',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerechtshof_Arnhem-Leeuwarden',
#   'Naam': 'Gerechtshof Arnhem-Leeuwarden',
#   'Afkorting': 'GHARL',
#   'Type': 'Gerechtshof',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerechtshof_Den_Haag',
#   'Naam': 'Gerechtshof Den Haag',
#   'Afkorting': 'GHDHA',
#   'Type': 'Gerechtshof',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerechtshof_Leeuwarden',
#   'Naam': 'Gerechtshof Leeuwarden',
#   'Afkorting': 'GHLEE',
#   'Type': 'Gerechtshof',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': "http://psi.rechtspraak.nl/instantie#Kantongerecht_'s-Gravenhage",
#   'Naam': "Kantongerecht 's-Gravenhage",
#   'Afkorting': 'KTGSGR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': "http://psi.rechtspraak.nl/instantie#Kantongerecht_'s-Hertogenbosch",
#   'Naam': "Kantongerecht 's-Hertogenbosch",
#   'Afkorting': 'KTGSHE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Alkmaar',
#   'Naam': 'Kantongerecht Alkmaar',
#   'Afkorting': 'KTGALK',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Almelo',
#   'Naam': 'Kantongerecht Almelo',
#   'Afkorting': 'KTGALM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Alphen_aan_den_Rijn',
#   'Naam': 'Kantongerecht Alphen aan den Rijn',
#   'Afkorting': 'KTGAAR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Amersfoort',
#   'Naam': 'Kantongerecht Amersfoort',
#   'Afkorting': 'KTGAMF',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Amsterdam',
#   'Naam': 'Kantongerecht Amsterdam',
#   'Afkorting': 'KTGAMS',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Apeldoorn',
#   'Naam': 'Kantongerecht Apeldoorn',
#   'Afkorting': 'KTGAPD',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtAppingedam',
#   'Naam': 'Kantongerecht Appingedam',
#   'Afkorting': 'KTGAPP',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Arnhem',
#   'Naam': 'Kantongerecht Arnhem',
#   'Afkorting': 'KTGARN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Assen',
#   'Naam': 'Kantongerecht Assen',
#   'Afkorting': 'KTGASS',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Beetsterzwaag',
#   'Naam': 'Kantongerecht Beetsterzwaag',
#   'Afkorting': 'KTGBEE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Bergen_op_Zoom',
#   'Naam': 'Kantongerecht Bergen op Zoom',
#   'Afkorting': 'KTGBOZ',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtBergum',
#   'Naam': 'Kantongerecht Bergum',
#   'Afkorting': 'KTGBER',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtBolsward',
#   'Naam': 'Kantongerecht Bolsward',
#   'Afkorting': 'KTGBOL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Boxmeer',
#   'Naam': 'Kantongerecht Boxmeer',
#   'Afkorting': 'KTGBOX',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Breda',
#   'Naam': 'Kantongerecht Breda',
#   'Afkorting': 'KTGBRE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtBreukelenNijenrode',
#   'Naam': 'Kantongerecht Breukelen-Nijenrode',
#   'Afkorting': 'KTGBRN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Brielle',
#   'Naam': 'Kantongerecht Brielle',
#   'Afkorting': 'KTGBRI',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Delft',
#   'Naam': 'Kantongerecht Delft',
#   'Afkorting': 'KTGDEL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Den_Helder',
#   'Naam': 'Kantongerecht Den Helder',
#   'Afkorting': 'KTGDHD',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Deventer',
#   'Naam': 'Kantongerecht Deventer',
#   'Afkorting': 'KTGDEV',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Dordrecht',
#   'Naam': 'Kantongerecht Dordrecht',
#   'Afkorting': 'KTGDOR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Eindhoven',
#   'Naam': 'Kantongerecht Eindhoven',
#   'Afkorting': 'KTGEIN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtElst',
#   'Naam': 'Kantongerecht Elst',
#   'Afkorting': 'KTGELS',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Emmen',
#   'Naam': 'Kantongerecht Emmen',
#   'Afkorting': 'KTGEMM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Enschede',
#   'Naam': 'Kantongerecht Enschede',
#   'Afkorting': 'KTGENS',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtGeldermalsen',
#   'Naam': 'Kantongerecht Geldermalsen',
#   'Afkorting': 'KTGGEL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtGoes',
#   'Naam': 'Kantongerecht Goes',
#   'Afkorting': 'KTGGOE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtGoor',
#   'Naam': 'Kantongerecht Goor',
#   'Afkorting': 'KTGGOO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Gorinchem',
#   'Naam': 'Kantongerecht Gorinchem',
#   'Afkorting': 'KTGGRC',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Gouda',
#   'Naam': 'Kantongerecht Gouda',
#   'Afkorting': 'KTGGOU',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Groenlo',
#   'Naam': 'Kantongerecht Groenlo',
#   'Afkorting': 'KTGGNL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Groningen',
#   'Naam': 'Kantongerecht Groningen',
#   'Afkorting': 'KTGGRO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtGulpen',
#   'Naam': 'Kantongerecht Gulpen',
#   'Afkorting': 'KTGGUL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Haarlem',
#   'Naam': 'Kantongerecht Haarlem',
#   'Afkorting': 'KTGHAA',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtHaarlemmermeer',
#   'Naam': 'Kantongerecht Haarlemmermeer',
#   'Afkorting': 'KTGHMM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Harderwijk',
#   'Naam': 'Kantongerecht Harderwijk',
#   'Afkorting': 'KTGHAR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Heerenveen',
#   'Naam': 'Kantongerecht Heerenveen',
#   'Afkorting': 'KTGHRV',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Heerlen',
#   'Naam': 'Kantongerecht Heerlen',
#   'Afkorting': 'KTGHRL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Helmond',
#   'Naam': 'Kantongerecht Helmond',
#   'Afkorting': 'KTGHMD',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Hilversum',
#   'Naam': 'Kantongerecht Hilversum',
#   'Afkorting': 'KTGHIL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Hoofddorp',
#   'Naam': 'Kantongerecht Hoofddorp',
#   'Afkorting': 'KTGHFD',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtHoogeveen',
#   'Naam': 'Kantongerecht Hoogeveen',
#   'Afkorting': 'KTGHOO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Hoorn',
#   'Naam': 'Kantongerecht Hoorn',
#   'Afkorting': 'KTGHRN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtKampen',
#   'Naam': 'Kantongerecht Kampen',
#   'Afkorting': 'KTGKAM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Leeuwarden',
#   'Naam': 'Kantongerecht Leeuwarden',
#   'Afkorting': 'KTGLEE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Leiden',
#   'Naam': 'Kantongerecht Leiden',
#   'Afkorting': 'KTGLDN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Lelystad',
#   'Naam': 'Kantongerecht Lelystad',
#   'Afkorting': 'KTGLLY',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtLemmer',
#   'Naam': 'Kantongerecht Lemmer',
#   'Afkorting': 'KTGLMM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Maastricht',
#   'Naam': 'Kantongerecht Maastricht',
#   'Afkorting': 'KTGMAA',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtMedemblik',
#   'Naam': 'Kantongerecht Medemblik',
#   'Afkorting': 'KTGMED',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Meppel',
#   'Naam': 'Kantongerecht Meppel',
#   'Afkorting': 'KTGMEP',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Middelburg',
#   'Naam': 'Kantongerecht Middelburg',
#   'Afkorting': 'KTGMID',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Nijmegen',
#   'Naam': 'Kantongerecht Nijmegen',
#   'Afkorting': 'KTGNMG',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtOmmen',
#   'Naam': 'Kantongerecht Ommen',
#   'Afkorting': 'KTGOMM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtOnderdendam',
#   'Naam': 'Kantongerecht Onderdendam',
#   'Afkorting': 'KTGOND',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Oostburg',
#   'Naam': 'Kantongerecht Oostburg',
#   'Afkorting': 'KTGOOS',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Oud-Beijerland',
#   'Naam': 'Kantongerecht Oud-Beijerland',
#   'Afkorting': 'KTGOBL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Paramaribo',
#   'Naam': 'Kantongerecht Paramaribo',
#   'Afkorting': 'KTGPAR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1965-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtPurmerend',
#   'Naam': 'Kantongerecht Purmerend',
#   'Afkorting': 'KTGPUR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtRidderkerk',
#   'Naam': 'Kantongerecht Ridderkerk',
#   'Afkorting': 'KTGRID',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Roermond',
#   'Naam': 'Kantongerecht Roermond',
#   'Afkorting': 'KTGROE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Rotterdam',
#   'Naam': 'Kantongerecht Rotterdam',
#   'Afkorting': 'KTGROT',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Schiedam',
#   'Naam': 'Kantongerecht Schiedam',
#   'Afkorting': 'KTGSCH',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtSchoonhoven',
#   'Naam': 'Kantongerecht Schoonhoven',
#   'Afkorting': 'KTGSOO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Sittard',
#   'Naam': 'Kantongerecht Sittard',
#   'Afkorting': 'KTGSIT',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtSliedrecht',
#   'Naam': 'Kantongerecht Sliedrecht',
#   'Afkorting': 'KTGSLI',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Sneek',
#   'Naam': 'Kantongerecht Sneek',
#   'Afkorting': 'KTGSNK',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Sommelsdijk',
#   'Naam': 'Kantongerecht Sommelsdijk',
#   'Afkorting': 'KTGSOM',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Steenwijk',
#   'Naam': 'Kantongerecht Steenwijk',
#   'Afkorting': 'KTGSTW',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Terborg',
#   'Naam': 'Kantongerecht Terborg',
#   'Afkorting': 'KTGTRB',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Terneuzen',
#   'Naam': 'Kantongerecht Terneuzen',
#   'Afkorting': 'KTGTRN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtTholen',
#   'Naam': 'Kantongerecht Tholen',
#   'Afkorting': 'KTGTHO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Tiel',
#   'Naam': 'Kantongerecht Tiel',
#   'Afkorting': 'KTGTIE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Tilburg',
#   'Naam': 'Kantongerecht Tilburg',
#   'Afkorting': 'KTGTIL',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Utrecht',
#   'Naam': 'Kantongerecht Utrecht',
#   'Afkorting': 'KTGUTR',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Veendam',
#   'Naam': 'Kantongerecht Veendam',
#   'Afkorting': 'KTGVEE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Venlo',
#   'Naam': 'Kantongerecht Venlo',
#   'Afkorting': 'KTGVEN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Wageningen',
#   'Naam': 'Kantongerecht Wageningen',
#   'Afkorting': 'KTGWAG',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtWeert',
#   'Naam': 'Kantongerecht Weert',
#   'Afkorting': 'KTGWRT',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Winschoten',
#   'Naam': 'Kantongerecht Winschoten',
#   'Afkorting': 'KTGWIN',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#KantongerechtWoerden',
#   'Naam': 'Kantongerecht Woerden',
#   'Afkorting': 'KTGWOE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zaandam',
#   'Naam': 'Kantongerecht Zaandam',
#   'Afkorting': 'KTGZAA',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zevenbergen',
#   'Naam': 'Kantongerecht Zevenbergen',
#   'Afkorting': 'KTGZEV',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zierikzee',
#   'Naam': 'Kantongerecht Zierikzee',
#   'Afkorting': 'KTGZIE',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zuidbroek',
#   'Naam': 'Kantongerecht Zuidbroek',
#   'Afkorting': 'KTGZUI',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zutphen',
#   'Naam': 'Kantongerecht Zutphen',
#   'Afkorting': 'KTGZUT',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie#Kantongerecht_Zwolle',
#   'Naam': 'Kantongerecht Zwolle',
#   'Afkorting': 'KTGZWO',
#   'Type': 'Kantongerecht',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2001-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/OCHM',
#   'Naam': 'Constitutioneel Hof Sint Maarten',
#   'Afkorting': 'OCHM',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GHACSMBES',
#   'Naam': 'Gemeenschappelijk Hof van Justitie van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba',
#   'Afkorting': 'OGHACMB',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GHvJAntil',
#   'Naam': 'Gemeenschappelijk Hof van Justitie van de Nederlandse Antillen en Aruba',
#   'Afkorting': 'OGHNAA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2010-10-09'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Gerecht_in_Ambtenarenzaken_van_Aruba_Curacao_Sint_Maarten_en_van_Bonaire_Sint_Eustatius_en_Saba',
#   'Naam': 'Gerecht in Ambtenarenzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba',
#   'Afkorting': 'OGAACMB',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://psi.rechtspraak.nl/giazna',
#   'Naam': 'Gerecht in Ambtenarenzaken van de Nederlandse Antillen',
#   'Afkorting': 'OGANA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2010-10-09'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GiEAB',
#   'Naam': 'Gerecht in Eerste Aanleg Bonaire',
#   'Afkorting': 'OGEAB',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2010-10-09'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GEA Aruba',
#   'Naam': 'Gerecht in Eerste Aanleg van Aruba',
#   'Afkorting': 'OGEAA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GEABES',
#   'Naam': 'Gerecht in eerste aanleg van Bonaire, Sint Eustatius en Saba',
#   'Afkorting': 'OGEABES',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GEAC',
#   'Naam': 'Gerecht in eerste aanleg van Curaçao',
#   'Afkorting': 'OGEAC',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GEAAntil',
#   'Naam': 'Gerecht in Eerste Aanleg van de Nederlandse Antillen',
#   'Afkorting': 'OGEANA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-10-09'},
#  {'Identifier': 'http://psi.rechtspraak.nl/GEASM',
#   'Naam': 'Gerecht in eerste aanleg van Sint Maarten',
#   'Afkorting': 'OGEAM',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/HvJAntil',
#   'Naam': 'Hof van Justitie van de Nederlandse Antillen',
#   'Afkorting': 'OHJNA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2000-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBAAntil',
#   'Naam': 'Raad van Beroep in Ambtenarenzaken (Nederlandse Antillen en Aruba)',
#   'Afkorting': 'ORBANAA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2010-10-09'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Raad_van_Beroep_in_Ambtenarenzaken_van_Aruba_Curacao_Sint_Maarten_en_van_Bonaire_Sint_Eustatius_en_Saba',
#   'Naam': 'Raad van Beroep in Ambtenarenzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba',
#   'Afkorting': 'ORBAACM',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://psi.rechtspraak.nl/RvBbel',
#   'Naam': 'Raad van Beroep voor Belastingzaken (Nederlandse Antillen en Aruba)',
#   'Afkorting': 'ORBBNAA',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2010-10-09'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Raad_van_Beroep_voor_Belastingzaken_van_Aruba_Curacao_Sint_Maarten_en_van_Bonaire_Sint_Eustatius_en_Saba',
#   'Naam': 'Raad van Beroep voor Belastingzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba',
#   'Afkorting': 'ORBBACM',
#   'Type': 'Koninkrijksinstantie',
#   'BeginDate': '2010-10-10'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Parket_bij_de_Hoge_Raad',
#   'Naam': 'Parket bij de Hoge Raad',
#   'Afkorting': 'PHR',
#   'Type': 'Parket',
#   'BeginDate': '1838-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_s-Gravenhage',
#   'Naam': "Rechtbank 's-Gravenhage",
#   'Afkorting': 'RBSGR',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': "http://standaarden.overheid.nl/owms/terms/Rechtbank_'s-Hertogenbosch",
#   'Naam': "Rechtbank 's-Hertogenbosch",
#   'Afkorting': 'RBSHE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Alkmaar',
#   'Naam': 'Rechtbank Alkmaar',
#   'Afkorting': 'RBALK',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Almelo',
#   'Naam': 'Rechtbank Almelo',
#   'Afkorting': 'RBALM',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Amsterdam',
#   'Naam': 'Rechtbank Amsterdam',
#   'Afkorting': 'RBAMS',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Arnhem',
#   'Naam': 'Rechtbank Arnhem',
#   'Afkorting': 'RBARN',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Assen',
#   'Naam': 'Rechtbank Assen',
#   'Afkorting': 'RBASS',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Breda',
#   'Naam': 'Rechtbank Breda',
#   'Afkorting': 'RBBRE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Den_Haag',
#   'Naam': 'Rechtbank Den Haag',
#   'Afkorting': 'RBDHA',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Dordrecht',
#   'Naam': 'Rechtbank Dordrecht',
#   'Afkorting': 'RBDOR',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Gelderland',
#   'Naam': 'Rechtbank Gelderland',
#   'Afkorting': 'RBGEL',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-04-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Groningen',
#   'Naam': 'Rechtbank Groningen',
#   'Afkorting': 'RBGRO',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Haarlem',
#   'Naam': 'Rechtbank Haarlem',
#   'Afkorting': 'RBHAA',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#RechtbankHeerenveen',
#   'Naam': 'Rechtbank Heerenveen',
#   'Afkorting': 'RBHRV',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1966-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Leeuwarden',
#   'Naam': 'Rechtbank Leeuwarden',
#   'Afkorting': 'RBLEE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Limburg',
#   'Naam': 'Rechtbank Limburg',
#   'Afkorting': 'RBLIM',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Maastricht',
#   'Naam': 'Rechtbank Maastricht',
#   'Afkorting': 'RBMAA',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Middelburg',
#   'Naam': 'Rechtbank Middelburg',
#   'Afkorting': 'RBMID',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Midden-Nederland',
#   'Naam': 'Rechtbank Midden-Nederland',
#   'Afkorting': 'RBMNE',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Noord-Holland',
#   'Naam': 'Rechtbank Noord-Holland',
#   'Afkorting': 'RBNHO',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Noord-Nederland',
#   'Naam': 'Rechtbank Noord-Nederland',
#   'Afkorting': 'RBNNE',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Oost-Brabant',
#   'Naam': 'Rechtbank Oost-Brabant',
#   'Afkorting': 'RBOBR',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Oost-Nederland',
#   'Naam': 'Rechtbank Oost-Nederland',
#   'Afkorting': 'RBONE',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01',
#   'EndDate': '2013-03-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Overijssel',
#   'Naam': 'Rechtbank Overijssel',
#   'Afkorting': 'RBOVE',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-04-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Roermond',
#   'Naam': 'Rechtbank Roermond',
#   'Afkorting': 'RBROE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Rotterdam',
#   'Naam': 'Rechtbank Rotterdam',
#   'Afkorting': 'RBROT',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#RechtbankTiel',
#   'Naam': 'Rechtbank Tiel',
#   'Afkorting': 'RBTIE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1966-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Utrecht',
#   'Naam': 'Rechtbank Utrecht',
#   'Afkorting': 'RBUTR',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#RechtbankWinschoten',
#   'Naam': 'Rechtbank Winschoten',
#   'Afkorting': 'RBWIN',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1966-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Zeeland-West-Brabant',
#   'Naam': 'Rechtbank Zeeland-West-Brabant',
#   'Afkorting': 'RBZWB',
#   'Type': 'Rechtbank',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/Kantongerecht/#RechtbankZierikzee',
#   'Naam': 'Rechtbank Zierikzee',
#   'Afkorting': 'RBZIE',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1966-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Zutphen',
#   'Naam': 'Rechtbank Zutphen',
#   'Afkorting': 'RBZUT',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Zwolle',
#   'Naam': 'Rechtbank Zwolle',
#   'Afkorting': 'RBZWO',
#   'Type': 'Rechtbank',
#   'BeginDate': '1913-01-01',
#   'EndDate': '2004-06-30'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Rechtbank_Zwolle-Lelystad',
#   'Naam': 'Rechtbank Zwolle-Lelystad',
#   'Afkorting': 'RBZLY',
#   'Type': 'Rechtbank',
#   'BeginDate': '2004-07-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tacakn',
#   'Naam': 'Accountantskamer NIVRA',
#   'Afkorting': 'TACAKN',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#CentraalCollegeTuchtrechtspraak',
#   'Naam': 'Centraal College Tuchtrechtspraak',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tcmt',
#   'Naam': 'Centraal Medisch Tuchtcollege',
#   'Afkorting': 'TCMT',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1913-01-01',
#   'EndDate': '1999-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzctg',
#   'Naam': 'Centraal Tuchtcollege voor de Gezondheidszorg',
#   'Afkorting': 'TGZCTG',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#CollegemedischtuchtrechtsGravenhage',
#   'Naam': "College medisch tuchtrecht 's-Gravenhage",
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#CollegemedischtuchtrechtAmsterdam',
#   'Naam': 'College medisch tuchtrecht Amsterdam',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#CollegemedischtuchtrechtEindhoven',
#   'Naam': 'College medisch tuchtrecht Eindhoven',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#CollegemedischtuchtrechtZwolle',
#   'Naam': 'College medisch tuchtrecht Zwolle',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tahvd',
#   'Naam': 'Hof van Discipline',
#   'Afkorting': 'TAHVD',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnoksgr',
#   'Naam': "Kamer van Toezicht over de notarissen en kandidaat-notarissen 's-Gravenhage",
#   'Afkorting': 'TNOKSGR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokshe',
#   'Naam': "Kamer van Toezicht over de notarissen en kandidaat-notarissen 's-Hertogenbosch",
#   'Afkorting': 'TNOKSHE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokalk',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Alkmaar',
#   'Afkorting': 'TNOKALK',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokalm',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Almelo',
#   'Afkorting': 'TNOKALM',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokams',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Amsterdam',
#   'Afkorting': 'TNOKAMS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokarn',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Arnhem',
#   'Afkorting': 'TNOKARN',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokass',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Assen',
#   'Afkorting': 'TNOKASS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokbre',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Breda',
#   'Afkorting': 'TNOKBRE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokdor',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Dordrecht',
#   'Afkorting': 'TNOKDOR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokgro',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Groningen',
#   'Afkorting': 'TNOKGRO',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokhaa',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Haarlem',
#   'Afkorting': 'TNOKHAA',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnoklee',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Leeuwarden',
#   'Afkorting': 'TNOKLEE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokmaa',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Maastricht',
#   'Afkorting': 'TNOKMAA',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokmid',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Middelburg',
#   'Afkorting': 'TNOKMID',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokroe',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Roermond',
#   'Afkorting': 'TNOKROE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokrot',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Rotterdam',
#   'Afkorting': 'TNOKROT',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokutr',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Utrecht',
#   'Afkorting': 'TNOKUTR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokzut',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Zutphen',
#   'Afkorting': 'TNOKZUT',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnokzly',
#   'Naam': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Zwolle-Lelystad',
#   'Afkorting': 'TNOKZLY',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgdkg',
#   'Naam': 'Kamer voor Gerechtsdeurwaarders',
#   'Afkorting': 'TGDKG',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnorshe',
#   'Naam': "Kamer voor het notariaat in het ressort 's-Hertogenbosch",
#   'Afkorting': 'TNORSHE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnorams',
#   'Naam': 'Kamer voor het notariaat in het ressort Amsterdam',
#   'Afkorting': 'TNORAMS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnorarl',
#   'Naam': 'Kamer voor het notariaat in het ressort Arnhem-Leeuwarden',
#   'Afkorting': 'TNORARL',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tnordha',
#   'Naam': 'Kamer voor het notariaat in het ressort Den Haag',
#   'Afkorting': 'TNORDHA',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#MedischTuchtcollegeEindhoven',
#   'Naam': 'Medisch Tuchtcollege Eindhoven',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#MedischTuchtcollegeGroningen',
#   'Naam': 'Medisch Tuchtcollege Groningen',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#MedischTuchtcollegeZwolle',
#   'Naam': 'Medisch Tuchtcollege Zwolle',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrsgr',
#   'Naam': "Raad van Discipline 's-Gravenhage",
#   'Afkorting': 'TADRSGR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrshe',
#   'Naam': "Raad van Discipline 's-Hertogenbosch",
#   'Afkorting': 'TADRSHE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrams',
#   'Naam': 'Raad van Discipline Amsterdam',
#   'Afkorting': 'TADRAMS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrarn',
#   'Naam': 'Raad van Discipline Arnhem',
#   'Afkorting': 'TADRARN',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrarl',
#   'Naam': 'Raad van Discipline Arnhem-Leeuwarden',
#   'Afkorting': 'TADRARL',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2013-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tadrlee',
#   'Naam': 'Raad van Discipline Leeuwarden',
#   'Afkorting': 'TADRLEE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01',
#   'EndDate': '2012-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/trmtsgr',
#   'Naam': "Regionaal Medisch Tuchtcollege 's Gravenhage",
#   'Afkorting': 'TRMTSGR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1930-07-01',
#   'EndDate': '1997-11-30'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/trmtams',
#   'Naam': 'Regionaal Medisch Tuchtcollege Amsterdam (v/h Medisch tuchtcollege Amsterdam)',
#   'Afkorting': 'TRMTAMS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1930-07-01',
#   'EndDate': '1997-11-30'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrsgr',
#   'Naam': "Regionaal Tuchtcollege voor de Gezondheidszorg 's-Gravenhage",
#   'Afkorting': 'TGZRSGR',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrshe',
#   'Naam': "Regionaal Tuchtcollege voor de Gezondheidszorg 's-Hertogenbosch",
#   'Afkorting': 'TGZRSHE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '2022-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrams',
#   'Naam': 'Regionaal Tuchtcollege voor de Gezondheidszorg Amsterdam',
#   'Afkorting': 'TGZRAMS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrein',
#   'Naam': 'Regionaal Tuchtcollege voor de Gezondheidszorg Eindhoven',
#   'Afkorting': 'TGZREIN',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01',
#   'EndDate': '2021-12-31'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrgro',
#   'Naam': 'Regionaal Tuchtcollege voor de Gezondheidszorg Groningen',
#   'Afkorting': 'TGZRGRO',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgzrzwo',
#   'Naam': 'Regionaal Tuchtcollege voor de Gezondheidszorg Zwolle',
#   'Afkorting': 'TGZRZWO',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1997-12-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tbpskal',
#   'Naam': 'Skal-Tuchtgerecht',
#   'Afkorting': 'TBPSKAL',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tlotl',
#   'Naam': 'Tuchtcollege loodsen',
#   'Afkorting': 'TLOTL',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tscts',
#   'Naam': 'Tuchtcollege voor de Scheepvaart',
#   'Afkorting': 'TSCTS',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tbbbkd',
#   'Naam': 'Tuchtgerecht Bloembollenkeuringsdienst',
#   'Afkorting': 'TBBBKD',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tgfkcb',
#   'Naam': 'Tuchtgerecht Kwaliteits-Controle-Bureau',
#   'Afkorting': 'TGFKCB',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/taktpa',
#   'Naam': 'Tuchtgerecht Productschap Akkerbouw',
#   'Afkorting': 'TAKTPA',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tpetpve',
#   'Naam': 'Tuchtgerecht Productschap Pluimvee en Eieren',
#   'Afkorting': 'TPETPVE',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tvvtpvv',
#   'Naam': 'Tuchtgerecht Productschap Vee en Vlees',
#   'Afkorting': 'TVVTPVV',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tvstpv',
#   'Naam': 'Tuchtgerecht Productschap Vis',
#   'Afkorting': 'TVSTPV',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#TuchtrechterPrijzenRotterdam',
#   'Naam': 'Tuchtrechter Prijzen Rotterdam',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#TuchtrechterVoedselvoorzieningLeeuwarden',
#   'Naam': 'Tuchtrechter Voedselvoorziening Leeuwarden',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/instantie/TuchtrechtelijkeInstantie/#TuchtrechterVoedselvoorzieningRotterdam',
#   'Naam': 'Tuchtrechter Voedselvoorziening Rotterdam',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tdivbc',
#   'Naam': 'Veterinair Beroepscollege',
#   'Afkorting': 'TDIVBC',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/tdivtc',
#   'Naam': 'Veterinair Tuchtcollege',
#   'Afkorting': 'TDIVTC',
#   'Type': 'TuchtrechtelijkeInstantie',
#   'BeginDate': '1950-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/College_van_Beroep_voor_het_bedrijfsleven',
#   'Naam': 'College van Beroep voor het bedrijfsleven',
#   'Afkorting': 'CBB',
#   'Type': 'TypeCBb',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Centrale_Raad_van_Beroep',
#   'Naam': 'Centrale Raad van Beroep',
#   'Afkorting': 'CRVB',
#   'Type': 'TypeCRvB',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Hoge_Raad_der_Nederlanden',
#   'Naam': 'Hoge Raad',
#   'Afkorting': 'HR',
#   'Type': 'TypeHr',
#   'BeginDate': '1838-01-01'},
#  {'Identifier': 'http://standaarden.overheid.nl/owms/terms/Raad_van_State',
#   'Naam': 'Raad van State',
#   'Afkorting': 'RVS',
#   'Type': 'TypeRvS',
#   'BeginDate': '1913-01-01'},
#  {'Identifier': 'http://psi.rechtspraak.nl/buitenlandseInstantie',
#   'Naam': 'Buitenlandse instanties',
#   'Afkorting': 'XX',
#   'Type': 'http://psi.rechtspraak.nl/buitenlandseInstantie'}]

# %% [markdown]
# ## Fetch names for gerechtscodes used in ECLIs

# %% [markdown]
# It seems that here we have to be a little more creative, and scape it from a webpage like the one mentioned in the code.
#
# Note that the page this uses is **not an authoritative list** - there was previously a typo in there (RBGL instead of RBGEL for Rechtbank Gelderland), but it's pretty good, and there is extra information there that can be practical.

# %%
# BeautifulSoup (bs4) is a library that makes it easier to scrape values from HTML with relatively simple code.
import bs4
bytedata = wetsuite.helpers.net.download('https://www.rechtspraak.nl/Uitspraken/Paginas/Volledige-lijst-Nederlandse-gerechtscodes.aspx')
soup = bs4.BeautifulSoup( bytedata )

# %%
gerechtcode_data = {}  # example item:    'AGAMS': {'abbrev':'AGAMS', 'name':'Ambtenarengerecht Amsterdam', 'extra': ['opgeheven','ambtenarengerecht'],}

# Here we try to imitate the rechtspraak.nl's website search's grouping,  which knows more than I do
# TODO: have an 'everything else' cateogry
groups = {  # grouping name -> [ list of gerechtcodes in it ]
    'Hoge Raad':['HR', 'PHR'],
    'Raad van State':['RVS'],
    'Centrale Raad van Beroep':['CRVB'],
    'College van Beroep voor het bedrijfsleven':['CBB'],
    'Gerechtshoven':[],
    'Rechtbanken':[],
    'Andere instanties binnen het koningkrijk':[],
}


table = soup.select('table.rnl-rteTable-default')[0]
for tr in table.find_all('tr'):
    curdata = { 'extra':[] }  # extra is a list of tags we add ourselves, intended to look for specific things a little easier
    tds = tr.find_all('td')
    if len(tds)==2: # implicitly ignores the header row, those are th
        td1, td2 = tds

        abbrev = td1.text   
        curdata['abbrev'] = abbrev

        name = td2.text   # note that there are sometimes elemements in here, for tooltips.  TODO: deal with that a little more explicitly  and/or  and check the result
        if ' (opgeheven)' in name:
            name = name.replace(' (opgeheven)','').strip()
            curdata['extra'].append( 'opgeheven' )
        curdata['name'] = name

        # group them by their codes     TODO: check these
        if abbrev.startswith('GH'):
            curdata['extra'].append('gerechtshof')
            groups['Gerechtshoven'].append( abbrev )
             
        if abbrev.startswith('RB'):
            curdata['extra'].append( 'rechtbank' )
            groups['Rechtbanken'].append( abbrev )

        if abbrev.startswith('KT'):
            curdata['extra'].append( 'kantongerecht' )
        if abbrev.startswith('AG'):
            curdata['extra'].append( 'ambtenarengerecht' )
        if abbrev.startswith('RVB') or abbrev.startswith('ORB'):
            curdata['extra'].append( 'raadvanberoep' )

        if abbrev.startswith('O'): # Aruba, Curacao, Sint Maarten, Bonaire, Sint Eustatius, Saba 
            curdata['extra'].append( 'eilanden' ) # O... seems to overlap with fairly few of the abovementioned categories, but TODO: look at that
            groups['Andere instanties binnen het koningkrijk'].append( abbrev )

        # sort of special cases, add so that you can more easily look for these
        if abbrev == 'HR':
            curdata['extra'].append( 'hr' ) 
        if abbrev == 'PHR':
            curdata['extra'].append( 'hr' ) 
        if abbrev == 'CBB':
            curdata['extra'].append( 'cbb' ) 
        if abbrev == 'CRVB':
            curdata['extra'].append( 'crvb' ) 
        if abbrev == 'RVS':
            curdata['extra'].append( 'rvs' ) 

        # add some groupings that may be useful
        if 'tucht' in name.lower() or 'raad van discipline' in name.lower():
            curdata['extra'].append( 'tucht' ) 

        if 'notarissen' in name.lower() or 'notariaat' in name.lower(): # TODO: not sure this is a useful grouping
            curdata['extra'].append( 'notar' ) 

        if abbrev == 'XX': 
            curdata['extra'].append( 'xx' ) 
            name = 'No code or not yet assigned, possibly international' # TODO: see if that's accurate wording.

        # Which ones have not been sorted?
        if len(curdata['extra'])==0 or len(curdata['extra'])==1 and curdata['extra'][0]=='opgeheven': 
            #print(abbrev, name)
            curdata['extra'].append( 'unsorted' ) 
        #   which are currently:
        #     CVBSTUF  College van Beroep Studiefinanciering
        #     DETARCO  Tariefcommissie
        #     TACAKN   Accountantskamer NIVRA
        #     TAHVD    Hof van Discipline
        #     TDIVBC   Veterinair Beroepscollege
        #     TGDKG    Kamer voor Gerechtsdeurwaarders

        gerechtcode_data[abbrev] = curdata

# %% [markdown]
# ## Review the data we just made

# %%
gerechtcode_data
# Out:
# {'AGAMS': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGAMS',
#   'name': 'Ambtenarengerecht Amsterdam'},
#  'AGARN': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGARN',
#   'name': 'Ambtenarengerecht Arnhem'},
#  'AGGRO': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGGRO',
#   'name': 'Ambtenarengerecht Groningen'},
#  'AGHAA': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGHAA',
#   'name': 'Ambtenarengerecht Haarlem'},
#  'AGROE': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGROE',
#   'name': 'Ambtenarengerecht Roermond'},
#  'AGROT': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGROT',
#   'name': 'Ambtenarengerecht Rotterdam'},
#  'AGSGR': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGSGR',
#   'name': "Ambtenarengerecht 's-Gravenhage"},
#  'AGSHE': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGSHE',
#   'name': "Ambtenarengerecht 's-Hertogenbosch"},
#  'AGUTR': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGUTR',
#   'name': 'Ambtenarengerecht Utrecht'},
#  'AGZWO': {'extra': ['opgeheven', 'ambtenarengerecht'],
#   'abbrev': 'AGZWO',
#   'name': 'Ambtenarengerecht Zwolle'},
#  'CBB': {'extra': ['cbb'],
#   'abbrev': 'CBB',
#   'name': 'College van Beroep voor het bedrijfsleven'},
#  'CRVB': {'extra': ['crvb'],
#   'abbrev': 'CRVB',
#   'name': 'Centrale Raad van Beroep'},
#  'CVBSTUF': {'extra': ['opgeheven', 'unsorted'],
#   'abbrev': 'CVBSTUF',
#   'name': 'College van Beroep Studiefinanciering'},
#  'DETARCO': {'extra': ['opgeheven', 'unsorted'],
#   'abbrev': 'DETARCO',
#   'name': 'Tariefcommissie'},
#  'GHAMS': {'extra': ['gerechtshof'],
#   'abbrev': 'GHAMS',
#   'name': 'Gerechtshof Amsterdam'},
#  'GHARL': {'extra': ['gerechtshof'],
#   'abbrev': 'GHARL',
#   'name': 'Gerechtshof Arnhem-Leeuwarden'},
#  'GHARN': {'extra': ['opgeheven', 'gerechtshof'],
#   'abbrev': 'GHARN',
#   'name': 'Gerechtshof Arnhem'},
#  'GHDHA': {'extra': ['gerechtshof'],
#   'abbrev': 'GHDHA',
#   'name': 'Gerechtshof Den Haag'},
#  'GHLEE': {'extra': ['opgeheven', 'gerechtshof'],
#   'abbrev': 'GHLEE',
#   'name': 'Gerechtshof Leeuwarden'},
#  'GHSGR': {'extra': ['opgeheven', 'gerechtshof'],
#   'abbrev': 'GHSGR',
#   'name': "Gerechtshof 's-Gravenhage"},
#  'GHSHE': {'extra': ['gerechtshof'],
#   'abbrev': 'GHSHE',
#   'name': "Gerechtshof 's-Hertogenbosch"},
#  'HR': {'extra': ['hr'], 'abbrev': 'HR', 'name': 'Hoge Raad'},
#  'KTGAAR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGAAR',
#   'name': 'Kantongerecht Alphen aan den Rijn'},
#  'KTGALK': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGALK',
#   'name': 'Kantongerecht Alkmaar'},
#  'KTGALM': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGALM',
#   'name': 'Kantongerecht Almelo'},
#  'KTGAMF': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGAMF',
#   'name': 'Kantongerecht Amersfoort'},
#  'KTGAMS': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGAMS',
#   'name': 'Kantongerecht Amsterdam'},
#  'KTGAPD': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGAPD',
#   'name': 'Kantongerecht Apeldoorn'},
#  'KTGARN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGARN',
#   'name': 'Kantongerecht Arnhem'},
#  'KTGASS': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGASS',
#   'name': 'Kantongerecht Assen'},
#  'KTGBEE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGBEE',
#   'name': 'Kantongerecht Beetsterzwaag'},
#  'KTGBOX': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGBOX',
#   'name': 'Kantongerecht Boxmeer'},
#  'KTGBOZ': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGBOZ',
#   'name': 'Kantongerecht Bergen op Zoom'},
#  'KTGBRE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGBRE',
#   'name': 'Kantongerecht Breda'},
#  'KTGBRI': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGBRI',
#   'name': 'Kantongerecht Brielle'},
#  'KTGDEL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGDEL',
#   'name': 'Kantongerecht Delft'},
#  'KTGDEV': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGDEV',
#   'name': 'Kantongerecht Deventer'},
#  'KTGDHD': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGDHD',
#   'name': 'Kantongerecht Den Helder'},
#  'KTGDOR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGDOR',
#   'name': 'Kantongerecht Dordrecht'},
#  'KTGEIN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGEIN',
#   'name': 'Kantongerecht Eindhoven'},
#  'KTGEMM': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGEMM',
#   'name': 'Kantongerecht Emmen'},
#  'KTGENS': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGENS',
#   'name': 'Kantongerecht Enschede'},
#  'KTGGNL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGGNL',
#   'name': 'Kantongerecht Groenlo'},
#  'KTGGOU': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGGOU',
#   'name': 'Kantongerecht Gouda'},
#  'KTGGRC': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGGRC',
#   'name': 'Kantongerecht Gorinchem'},
#  'KTGGRO': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGGRO',
#   'name': 'Kantongerecht Groningen'},
#  'KTGHAA': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHAA',
#   'name': 'Kantongerecht Haarlem'},
#  'KTGHAR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHAR',
#   'name': 'Kantongerecht Harderwijk'},
#  'KTGHFD': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHFD',
#   'name': 'Kantongerecht Hoofddorp'},
#  'KTGHIL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHIL',
#   'name': 'Kantongerecht Hilversum'},
#  'KTGHMD': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHMD',
#   'name': 'Kantongerecht Helmond'},
#  'KTGHRL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHRL',
#   'name': 'Kantongerecht Heerlen'},
#  'KTGHRN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHRN',
#   'name': 'Kantongerecht Hoorn'},
#  'KTGHRV': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGHRV',
#   'name': 'Kantongerecht Heerenveen'},
#  'KTGLDN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGLDN',
#   'name': 'Kantongerecht Leiden'},
#  'KTGLEE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGLEE',
#   'name': 'Kantongerecht Leeuwarden'},
#  'KTGLLY': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGLLY',
#   'name': 'Kantongerecht Lelystad'},
#  'KTGMAA': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGMAA',
#   'name': 'Kantongerecht Maastricht'},
#  'KTGMEP': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGMEP',
#   'name': 'Kantongerecht Meppel'},
#  'KTGMID': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGMID',
#   'name': 'Kantongerecht Middelburg'},
#  'KTGNMG': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGNMG',
#   'name': 'Kantongerecht Nijmegen'},
#  'KTGOBL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGOBL',
#   'name': 'Kantongerecht Oud-Beijerland'},
#  'KTGOOS': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGOOS',
#   'name': 'Kantongerecht Oostburg'},
#  'KTGPAR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGPAR',
#   'name': 'Kantongerecht Parimaribo'},
#  'KTGROE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGROE',
#   'name': 'Kantongerecht Roermond'},
#  'KTGROT': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGROT',
#   'name': 'Kantongerecht Rotterdam'},
#  'KTGSCH': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSCH',
#   'name': 'Kantongerecht Schiedam'},
#  'KTGSGR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSGR',
#   'name': "Kantongerecht 's-Gravenhage"},
#  'KTGSHE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSHE',
#   'name': "Kantongerecht 's-Hertogenbosch"},
#  'KTGSIT': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSIT',
#   'name': 'Kantongerecht Sittard'},
#  'KTGSNK': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSNK',
#   'name': 'Kantongerecht Sneek'},
#  'KTGSOM': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSOM',
#   'name': 'Kantongerecht Sommelsdijk'},
#  'KTGSTW': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGSTW',
#   'name': 'Kantongerecht Steenwijk'},
#  'KTGTIE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGTIE',
#   'name': 'Kantongerecht Tiel'},
#  'KTGTIL': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGTIL',
#   'name': 'Kantongerecht Tilburg'},
#  'KTGTRB': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGTRB',
#   'name': 'Kantongerecht Terborg'},
#  'KTGTRN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGTRN',
#   'name': 'Kantongerecht Terneuzen'},
#  'KTGUTR': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGUTR',
#   'name': 'Kantongerecht Utrecht'},
#  'KTGVEE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGVEE',
#   'name': 'Kantongerecht Veendam'},
#  'KTGVEN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGVEN',
#   'name': 'Kantongerecht Venlo'},
#  'KTGWAG': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGWAG',
#   'name': 'Kantongerecht Wageningen'},
#  'KTGWIN': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGWIN',
#   'name': 'Kantongerecht Winschoten'},
#  'KTGZAA': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZAA',
#   'name': 'Kantongerecht Zaandam'},
#  'KTGZEV': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZEV',
#   'name': 'Kantongerecht Zevenbergen'},
#  'KTGZIE': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZIE',
#   'name': 'Kantongerecht Zierikzee'},
#  'KTGZUI': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZUI',
#   'name': 'Kantongerecht Zuidbroek'},
#  'KTGZUT': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZUT',
#   'name': 'Kantongerecht Zutphen'},
#  'KTGZWO': {'extra': ['opgeheven', 'kantongerecht'],
#   'abbrev': 'KTGZWO',
#   'name': 'Kantongerecht Zwolle'},
#  'OCHM': {'extra': ['eilanden'],
#   'abbrev': 'OCHM',
#   'name': 'Constitutioneel Hof Sint Maarten'},
#  'OGAACMB': {'extra': ['eilanden'],
#   'abbrev': 'OGAACMB',
#   'name': 'Gerecht in Ambtenarenzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba'},
#  'OGANA': {'extra': ['opgeheven', 'eilanden'],
#   'abbrev': 'OGANA',
#   'name': 'Gerecht in Ambtenarenzaken van de Nederlandse Antillen'},
#  'OGEAA': {'extra': ['eilanden'],
#   'abbrev': 'OGEAA',
#   'name': 'Gerecht in Eerste Aanleg van Aruba'},
#  'OGEAB': {'extra': ['opgeheven', 'eilanden'],
#   'abbrev': 'OGEAB',
#   'name': 'Gerecht in Eerste Aanleg Bonaire'},
#  'OGEABES': {'extra': ['eilanden'],
#   'abbrev': 'OGEABES',
#   'name': 'Gerecht in eerste aanleg van Bonaire, Sint Eustatius en Saba'},
#  'OGEAC': {'extra': ['eilanden'],
#   'abbrev': 'OGEAC',
#   'name': 'Gerecht in eerste aanleg van Curaçao'},
#  'OGEAM': {'extra': ['eilanden'],
#   'abbrev': 'OGEAM',
#   'name': 'Gerecht in eerste aanleg van Sint Maarten'},
#  'OGEANA': {'extra': ['opgeheven', 'eilanden'],
#   'abbrev': 'OGEANA',
#   'name': 'Gerecht in Eerste Aanleg van de Nederlandse Antillen'},
#  'OGHACMB': {'extra': ['eilanden'],
#   'abbrev': 'OGHACMB',
#   'name': 'Gemeenschappelijk Hof van Justitie van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba'},
#  'OGHNAA': {'extra': ['opgeheven', 'eilanden'],
#   'abbrev': 'OGHNAA',
#   'name': 'Gemeenschappelijk Hof van Justitie van de Nederlandse Antillen en Aruba'},
#  'OHJNA': {'extra': ['opgeheven', 'eilanden'],
#   'abbrev': 'OHJNA',
#   'name': 'Hof van Justitie van de Nederlandse Antillen'},
#  'ORBAACM': {'extra': ['raadvanberoep', 'eilanden'],
#   'abbrev': 'ORBAACM',
#   'name': 'Raad van Beroep in Ambtenarenzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba'},
#  'ORBANAA': {'extra': ['opgeheven', 'raadvanberoep', 'eilanden'],
#   'abbrev': 'ORBANAA',
#   'name': 'Raad van Beroep in Ambtenarenzaken (Nederlandse Antillen en Aruba)'},
#  'ORBBACM': {'extra': ['raadvanberoep', 'eilanden'],
#   'abbrev': 'ORBBACM',
#   'name': 'Raad van Beroep voor Belastingzaken van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba'},
#  'ORBBNAA': {'extra': ['opgeheven', 'raadvanberoep', 'eilanden'],
#   'abbrev': 'ORBBNAA',
#   'name': 'Raad van Beroep voor Belastingzaken (Nederlandse Antillen en Aruba)'},
#  'PHR': {'extra': ['hr'], 'abbrev': 'PHR', 'name': 'Parket bij de Hoge Raad'},
#  'RBALK': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBALK',
#   'name': 'Rechtbank Alkmaar'},
#  'RBALM': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBALM',
#   'name': 'Rechtbank Almelo'},
#  'RBAMS': {'extra': ['rechtbank'],
#   'abbrev': 'RBAMS',
#   'name': 'Rechtbank Amsterdam'},
#  'RBARN': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBARN',
#   'name': 'Rechtbank Arnhem'},
#  'RBASS': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBASS',
#   'name': 'Rechtbank Assen'},
#  'RBBRE': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBBRE',
#   'name': 'Rechtbank Breda'},
#  'RBDHA': {'extra': ['rechtbank'],
#   'abbrev': 'RBDHA',
#   'name': 'Rechtbank Den Haag'},
#  'RBDOR': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBDOR',
#   'name': 'Rechtbank Dordrecht'},
#  'RBGEL': {'extra': ['rechtbank'],
#   'abbrev': 'RBGEL',
#   'name': 'Rechtbank Gelderland'},
#  'RBGRO': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBGRO',
#   'name': 'Rechtbank Groningen'},
#  'RBHAA': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBHAA',
#   'name': 'Rechtbank Haarlem'},
#  'RBLEE': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBLEE',
#   'name': 'Rechtbank Leeuwarden'},
#  'RBLIM': {'extra': ['rechtbank'],
#   'abbrev': 'RBLIM',
#   'name': 'Rechtbank Limburg'},
#  'RBMAA': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBMAA',
#   'name': 'Rechtbank Maastricht'},
#  'RBMID': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBMID',
#   'name': 'Rechtbank Middelburg'},
#  'RBMNE': {'extra': ['rechtbank'],
#   'abbrev': 'RBMNE',
#   'name': 'Rechtbank Midden-Nederland'},
#  'RBNHO': {'extra': ['rechtbank'],
#   'abbrev': 'RBNHO',
#   'name': 'Rechtbank Noord-Holland'},
#  'RBNNE': {'extra': ['rechtbank'],
#   'abbrev': 'RBNNE',
#   'name': 'Rechtbank Noord-Nederland'},
#  'RBOBR': {'extra': ['rechtbank'],
#   'abbrev': 'RBOBR',
#   'name': 'Rechtbank Oost-Brabant'},
#  'RBONE': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBONE',
#   'name': 'Rechtbank Oost-Nederland'},
#  'RBOVE': {'extra': ['rechtbank'],
#   'abbrev': 'RBOVE',
#   'name': 'Rechtbank Overijssel'},
#  'RBROE': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBROE',
#   'name': 'Rechtbank Roermond'},
#  'RBROT': {'extra': ['rechtbank'],
#   'abbrev': 'RBROT',
#   'name': 'Rechtbank Rotterdam'},
#  'RBSGR': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBSGR',
#   'name': "Rechtbank 's-Gravenhage"},
#  'RBSHE': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBSHE',
#   'name': "Rechtbank 's-Hertogenbosch"},
#  'RBUTR': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBUTR',
#   'name': 'Rechtbank Utrecht'},
#  'RBZLY ': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBZLY ',
#   'name': 'Rechtbank Zwolle-Lelystad'},
#  'RBZUT': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBZUT',
#   'name': 'Rechtbank Zutphen'},
#  'RBZWB': {'extra': ['rechtbank'],
#   'abbrev': 'RBZWB',
#   'name': 'Rechtbank Zeeland-West-Brabant'},
#  'RBZWO': {'extra': ['opgeheven', 'rechtbank'],
#   'abbrev': 'RBZWO',
#   'name': 'Rechtbank Zwolle'},
#  'RVBALK': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBALK',
#   'name': 'Raad van beroep Alkmaar'},
#  'RVBAMS': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBAMS',
#   'name': 'Raad van beroep Amsterdam'},
#  'RVBARN': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBARN',
#   'name': 'Raad van beroep Arnhem'},
#  'RVBBRE': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBBRE',
#   'name': 'Raad van beroep Breda'},
#  'RVBGRO': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBGRO',
#   'name': 'Raad van beroep Groningen'},
#  'RVBHAA': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBHAA',
#   'name': 'Raad van beroep Haarlem'},
#  'RVBLDN': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBLDN',
#   'name': 'Raad van beroep Leiden'},
#  'RVBLEE': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBLEE',
#   'name': 'Raad van beroep Leeuwarden'},
#  'RVBMID': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBMID',
#   'name': 'Raad van beroep Middelburg'},
#  'RVBROE': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBROE',
#   'name': 'Raad van beroep Roermond'},
#  'RVBROT': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBROT',
#   'name': 'Raad van beroep Rotterdam'},
#  'RVBSGR': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBSGR',
#   'name': "Raad van beroep 's-Gravenhage"},
#  'RVBSHE': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBSHE',
#   'name': "Raad van beroep 's-Hertogenbosch"},
#  'RVBTIL': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBTIL',
#   'name': 'Raad van beroep Tilburg'},
#  'RVBUTR': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBUTR',
#   'name': 'Raad van beroep Utrecht'},
#  'RVBZWO': {'extra': ['opgeheven', 'raadvanberoep'],
#   'abbrev': 'RVBZWO',
#   'name': 'Raad van beroep Zwolle'},
#  'RVS': {'extra': ['rvs'], 'abbrev': 'RVS', 'name': 'Raad van State'},
#  'TACAKN': {'extra': ['unsorted'],
#   'abbrev': 'TACAKN',
#   'name': 'Accountantskamer NIVRA'},
#  'TADRAMS': {'extra': ['tucht'],
#   'abbrev': 'TADRAMS',
#   'name': 'Raad van Discipline Amsterdam'},
#  'TADRARL': {'extra': ['tucht'],
#   'abbrev': 'TADRARL',
#   'name': 'Raad van Discipline Arnhem-Leeuwarden'},
#  'TADRARN': {'extra': ['opgeheven', 'tucht'],
#   'abbrev': 'TADRARN',
#   'name': 'Raad van Discipline Arnhem'},
#  'TADRLEE': {'extra': ['opgeheven', 'tucht'],
#   'abbrev': 'TADRLEE',
#   'name': 'Raad van Discipline Leeuwarden'},
#  'TADRSGR': {'extra': ['tucht'],
#   'abbrev': 'TADRSGR',
#   'name': "Raad van Discipline 's-Gravenhage"},
#  'TADRSHE': {'extra': ['tucht'],
#   'abbrev': 'TADRSHE',
#   'name': "Raad van Discipline 's-Hertogenbosch"},
#  'TAHVD': {'extra': ['unsorted'],
#   'abbrev': 'TAHVD',
#   'name': 'Hof van Discipline'},
#  'TAKTPA': {'extra': ['tucht'],
#   'abbrev': 'TAKTPA',
#   'name': 'Tuchtgerecht Productschap Akkerbouw'},
#  'TBBBKD': {'extra': ['tucht'],
#   'abbrev': 'TBBBKD',
#   'name': 'Tuchtgerecht Bloembollenkeuringsdienst'},
#  'TBPSKAL': {'extra': ['tucht'],
#   'abbrev': 'TBPSKAL',
#   'name': 'Skal-Tuchtgerecht'},
#  'TDIVBC': {'extra': ['unsorted'],
#   'abbrev': 'TDIVBC',
#   'name': 'Veterinair Beroepscollege'},
#  'TDIVTC': {'extra': ['tucht'],
#   'abbrev': 'TDIVTC',
#   'name': 'Veterinair Tuchtcollege'},
#  'TGDKG': {'extra': ['unsorted'],
#   'abbrev': 'TGDKG',
#   'name': 'Kamer voor Gerechtsdeurwaarders'},
#  'TGFKCB': {'extra': ['tucht'],
#   'abbrev': 'TGFKCB',
#   'name': 'Tuchtgerecht Kwaliteits-Controle-Bureau'},
#  'TGZCTG': {'extra': ['tucht'],
#   'abbrev': 'TGZCTG',
#   'name': 'Centraal Tuchtcollege voor de Gezondheidszorg'},
#  'TGZRAMS': {'extra': ['tucht'],
#   'abbrev': 'TGZRAMS',
#   'name': 'Regionaal Tuchtcollege voor de Gezondheidszorg Amsterdam'},
#  'TGZREIN': {'extra': ['tucht'],
#   'abbrev': 'TGZREIN',
#   'name': 'Regionaal Tuchtcollege voor de Gezondheidszorg Eindhoven'},
#  'TGZRGRO': {'extra': ['tucht'],
#   'abbrev': 'TGZRGRO',
#   'name': 'Regionaal Tuchtcollege voor de Gezondheidszorg Groningen'},
#  'TGZRSGR': {'extra': ['tucht'],
#   'abbrev': 'TGZRSGR',
#   'name': "Regionaal Tuchtcollege voor de Gezondheidszorg 's-Gravenhage"},
#  'TGZRZWO': {'extra': ['tucht'],
#   'abbrev': 'TGZRZWO',
#   'name': 'Regionaal Tuchtcollege voor de Gezondheidszorg Zwolle'},
#  'TNOKALK': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKALK',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Alkmaar'},
#  'TNOKALM': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKALM',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Almelo'},
#  'TNOKAMS': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKAMS',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Amsterdam'},
#  'TNOKARN': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKARN',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Arnhem'},
#  'TNOKASS': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKASS',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Assen'},
#  'TNOKBRE': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKBRE',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Breda'},
#  'TNOKDOR': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKDOR',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Dordrecht'},
#  'TNOKGRO': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKGRO',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Groningen'},
#  'TNOKHAA': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKHAA',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Haarlem'},
#  'TNOKLEE': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKLEE',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Leeuwarden'},
#  'TNOKMAA': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKMAA',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Maastricht'},
#  'TNOKMID': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKMID',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Middelburg'},
#  'TNOKROE': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKROE',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Roermond'},
#  'TNOKROT': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKROT',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Rotterdam'},
#  'TNOKSGR': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKSGR',
#   'name': "Kamer van Toezicht over de notarissen en kandidaat-notarissen 's-Gravenhage"},
#  'TNOKSHE': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKSHE',
#   'name': "Kamer van Toezicht over de notarissen en kandidaat-notarissen 's-Hertogenbosch"},
#  'TNOKUTR': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKUTR',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen Utrecht'},
#  'TNOKZLY': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKZLY',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen\xa0Zwolle-Lelystad'},
#  'TNOKZUT': {'extra': ['opgeheven', 'notar'],
#   'abbrev': 'TNOKZUT',
#   'name': 'Kamer van Toezicht over de notarissen en kandidaat-notarissen\xa0Zutphen'},
#  'TNORAMS': {'extra': ['notar'],
#   'abbrev': 'TNORAMS',
#   'name': 'Kamer voor het notariaat in het ressort Amsterdam'},
#  'TNORARL': {'extra': ['notar'],
#   'abbrev': 'TNORARL',
#   'name': 'Kamer voor het notariaat in het ressort Arnhem-Leeuwarden'},
#  'TNORDHA': {'extra': ['notar'],
#   'abbrev': 'TNORDHA',
#   'name': 'Kamer voor het notariaat in het ressort Den Haag'},
#  'TNORSHE': {'extra': ['notar'],
#   'abbrev': 'TNORSHE',
#   'name': "Kamer voor het notariaat in het ressort 's-Hertogenbosch"},
#  'TPETPVE': {'extra': ['tucht'],
#   'abbrev': 'TPETPVE',
#   'name': 'Tuchtgerecht Productschap Pluimvee en Eieren'},
#  'TSCTS': {'extra': ['tucht'],
#   'abbrev': 'TSCTS',
#   'name': 'Tuchtcollege voor de Scheepvaart'},
#  'TVSTPV': {'extra': ['tucht'],
#   'abbrev': 'TVSTPV',
#   'name': 'Tuchtgerecht Productschap Vis'},
#  'TVVTPVV': {'extra': ['tucht'],
#   'abbrev': 'TVVTPVV',
#   'name': 'Tuchtgerecht Productschap Vee en Vlees'},
#  'XX': {'extra': ['xx'],
#   'abbrev': 'XX',
#   'name': "Gerechtscode voor uitspraken van nationale rechterlijke en niet-rechterlijke instanties die geen eigen gerechtscode hebben, of voor uitspraken van buitenlandse, Europese of internationale instanties waaraan door het daartoe bevoegde orgaan (nog) geen eigen ECLI is toegekend (artikel 1 lid 1 sub c onder vii van de Annex bij de 'Raadsconclusies waarin de invoering wordt aanbevolen van een Europese identificatiecode voor jurisprudentie (ECLI), en van een minimumaantal uniforme metagegevens betreffende jurisprudentie' (2011/C 127/01)) "}}

# %%
import pprint
with open( 'gerechtcodes.py', 'w' ) as f:
    f.write( 'data = ' + pprint.pformat( gerechtcode_data) )

# %%
groups
# Out:
# {'Hoge Raad': ['HR', 'PHR'],
#  'Raad van State': ['RVS'],
#  'Centrale Raad van Beroep': ['CRVB'],
#  'College van Beroep voor het bedrijfsleven': ['CBB'],
#  'Gerechtshoven': ['GHAMS',
#   'GHARL',
#   'GHARN',
#   'GHDHA',
#   'GHLEE',
#   'GHSGR',
#   'GHSHE'],
#  'Rechtbanken': ['RBALK',
#   'RBALM',
#   'RBAMS',
#   'RBARN',
#   'RBASS',
#   'RBBRE',
#   'RBDHA',
#   'RBDOR',
#   'RBGEL',
#   'RBGRO',
#   'RBHAA',
#   'RBLEE',
#   'RBLIM',
#   'RBMAA',
#   'RBMID',
#   'RBMNE',
#   'RBNHO',
#   'RBNNE',
#   'RBOBR',
#   'RBONE',
#   'RBOVE',
#   'RBROE',
#   'RBROT',
#   'RBSGR',
#   'RBSHE',
#   'RBUTR',
#   'RBZLY ',
#   'RBZUT',
#   'RBZWB',
#   'RBZWO'],
#  'Andere instanties binnen het koningkrijk': ['OCHM',
#   'OGAACMB',
#   'OGANA',
#   'OGEAA',
#   'OGEAB',
#   'OGEABES',
#   'OGEAC',
#   'OGEAM',
#   'OGEANA',
#   'OGHACMB',
#   'OGHNAA',
#   'OHJNA',
#   'ORBAACM',
#   'ORBANAA',
#   'ORBBACM',
#   'ORBBNAA']}

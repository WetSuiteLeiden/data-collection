# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/data-collection/blob/master/api_tweede_kamer_part2_second_api_verslagen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Purpose of this notebook
#
# Continuing from part 1 -- The SyncFeed API is perfectly functional,
# though it leaves you to do interpretation of the relations yourself, so let's see if the OData API is any more help.

# %% [markdown]
# ### OData interface
#
# There is a helpful library out there, [tkapi](https://github.com/openkamer/tkapi), which means much less work for us.

# %%
# if you haven't already:
# !pip3 install tkapi

# %%
import collections
import wetsuite.helpers.localdata
import wetsuite.helpers.split
from tkapi.document import Document, DocumentSoort
import tkapi, tkapi.document

# %%
# API object we'll be using a few times
api = tkapi.TKApi()

# %%
# Get an idea of what this API even does
#   the things that fetch are function calls.

list(name   for name in dir(api)   if name.startswith('get_'))
# Out:
# ['get_activiteiten',
#  'get_agendapunten',
#  'get_all_items',
#  'get_antwoorden',
#  'get_besluiten',
#  'get_commissies',
#  'get_documenten',
#  'get_dossiers',
#  'get_fractie_zetels',
#  'get_fracties',
#  'get_geschenken',
#  'get_item',
#  'get_items',
#  'get_kamervragen',
#  'get_personen',
#  'get_reizen',
#  'get_related',
#  'get_stemmingen',
#  'get_vergaderingen',
#  'get_verslagen',
#  'get_verslagen_van_algemeen_overleg',
#  'get_zaken']

# %% [markdown]
# ### How about verslagen?
#
# Say we want verslagen from commission debates.
#
# Alright, let's look at `get_verslagen()`

# %%
all_verslagen = api.get_verslagen( ) # currently ~20K items, will take a few dozen seconds to fetch the metadata of
len(all_verslagen)
# Out:
# 19904

# %%
#these are objects:
first_verslag = all_verslagen[0]

first_verslag

# %%
# ...so you're probably looking for the parameters on them. 
# The documentation helps a little, but also we can inspect that object:

list( name  for name in dir(all_verslagen[0])   if not name.startswith('_'))
# Out:
# ['begin_date_key',
#  'create_filter',
#  'end_date_key',
#  'expand_params',
#  'filter_param',
#  'get_date_from_datetime_or_none',
#  'get_date_or_none',
#  'get_datetime_or_none',
#  'get_param_expand',
#  'get_params_default',
#  'get_property_enum_or_none',
#  'get_property_or_empty_string',
#  'get_property_or_none',
#  'get_resource_url_or_none',
#  'get_year_or_none',
#  'gewijzigd_op',
#  'id',
#  'orderby_param',
#  'print_json',
#  'related_item',
#  'related_items',
#  'related_items_deep',
#  'soort',
#  'status',
#  'type',
#  'url',
#  'vergadering']

# %%
# let's look at the values of some:
first_verslag.gewijzigd_op.date(), first_verslag.soort, first_verslag.status, first_verslag.type, first_verslag.url, first_verslag.vergadering
# Out:
# (datetime.date(2024, 6, 5),
#  <VerslagSoort.TUSSENPUBLICATIE: 'Tussenpublicatie'>,
#  <VerslagStatus.ONGECORRIGEERD: 'Ongecorrigeerd'>,
#  'Verslag',
#  'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Verslag(7c3d4173-6528-4f1b-9dd4-3eba1e0bd322)',
#  <tkapi.vergadering.Vergadering at 0x7ff5efe378e0>)

# %% [markdown]
# It seems that soort, status, and type are not very helpful.
#
# Also, it becomes clear that we should have read the documentation/model a little better -- these verslagen seem specific to vergaderingen.
#
# How about sorting through _documents_, by type?

# %%
# NOTE: YOU MAY WISH TO SKIP THIS and go to the part where we do it properly.
# ..because when you remove that 10000-item limit to count _everthing_, this seems to take half an hour, and easily fails.
all_documenten = api.get_documenten( max_items=10000 ) 

# count soorten
soorten = collections.defaultdict(list)
for document in all_documenten:
    try:
        soorten[ str(document.soort).split(".",1)[1] ].append( document ) # takes the enum name (rather than value) and splits off the DocumentSoort.
    except Exception as e:
        print("SKIP invalid soort: %s"%(e))

# print soort  sorted by count, descending
soorten_by_count = sorted( list( soorten.items() ), key=lambda pair: len(pair[1]), reverse=True )
for soort, doclist in soorten_by_count:
    print( f'{len(doclist):7d}  {soort}')
# Out:
#    2531  BRIEF_REGERING
#    1274  BIJLAGE
#     871  SCHRIFTELIJKE_VRAGEN
#     558  ANTWOORD_SCHRIFTELIJKE_VRAGEN
#     545  CONVOCATIE_COMMISSIEACTIVITEIT
#     542  BRIEF_COMMISSIE_AAN_BEWINDSPERSOON
#     464  MOTIE
#     195  VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#     183  MEMORIE_VAN_TOELICHTING
#     182  VOORSTEL_VAN_WET
#     178  STENOGRAM
#     156  KONINKLIJKE_BOODSCHAP
#     151  MEDEDELING_UITSTEL_ANTWOORD
#     121  VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG
#     119  AMENDEMENT
#     116  NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#     114  BRIEF_LID__FRACTIE
#     114  AGENDA_PROCEDUREVERGADERING
#     105  NOTA_VAN_WIJZIGING
#     102  BESLUITENLIJST_PROCEDUREVERGADERING
#      94  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT
#      89  LIJST_VAN_VRAGEN
#      88  MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#      85  VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#      82  SPREKERSLIJST
#      77  LIJST_VAN_VRAGEN_EN_ANTWOORDEN
#      72  VERSLAG_VAN_EEN_SCHRIFTELIJK_OVERLEG
#      72  BRIEF_COMMISSIE
#      71  GELEIDENDE_BRIEF
#      71  CONVOCATIE_INBRENG
#      50  NOTA_VAN_VERBETERING
#      46  VERSLAG_HOUDENDE_EEN_LIJST_VAN_VRAGEN_EN_ANTWOORDEN
#      43  BIJGEWERKTE_TEKST
#      39  NADER_RAPPORT
#      34  EINDTEKST
#      30  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#      26  MONDELINGE_VRAGEN
#      25  AMENDEMENT_GEWIJZIGD_NADER_VERVANGEND
#      23  BRIEF_KAMER
#      23  MOTIE_GEWIJZIGDNADER
#      23  LIJST_VAN_INGEKOMEN_STUKKEN
#      22  VERSLAG_COMMISSIE_VERZOEKSCHRIFTEN_EN_DE_BURGERINITIATIEVEN
#      21  AANBIEDINGSBRIEF
#      20  NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#      20  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#      18  RAPPORT_ALGEMENE_REKENKAMER
#      18  BRIEF_ALGEMENE_REKENKAMER
#      13  OORSPRONKELIJKE_TEKST
#      13  STEMMINGSLIJST
#       9  MEDEDELING
#       8  STEMMINGSUITSLAGEN
#       7  VERSLAG_VAN_EEN_BIJEENKOMST
#       7  EU_VOORSTEL
#       6  VERSLAG_VAN_EEN_WETGEVINGSOVERLEG
#       5  NOTA
#       5  INITIATIEFNOTA
#       5  AGENDA_PLENAIRE_VERGADERING
#       3  VERSLAG_VAN_EEN_WERKBEZOEK
#       3  VERSLAG_VAN_EEN_HOORZITTING__RONDETAFELGESPREK
#       2  VOORSTEL_TOT_WIJZIGING_REGLEMENT_VAN_ORDE
#       2  AANHANGSEL_VAN_DE_HANDELINGEN
#       2  ANTWOORD_SCHRIFTELIJKE_VRAGEN_NADER
#       1  BRIEF_CTIVD
#       1  JAARVERSLAG
#       1  ADVIES_VAN_ANDERE_ADVIESORGANEN
#       1  VOORDRACHT
#       1  RAPPORT
#       1  INTERPELLATIEVRAGEN
#       1  ADVIES_AAN_PRESIDIUM

# %% [markdown]
# Counting is nice to see actual use, but we already can know the right documentsoort without it:
# in the middle of the following is `VERSLAG_VAN_EEN_COMMISSIEDEBAT`, which has our example wishes covered.

# %%
# list all-uppercase attributes
list(name   for name in dir(DocumentSoort)   if name == name.upper())
# Out:
# ['AANBIEDINGSBRIEF',
#  'AANHANGSEL_VAN_DE_HANDELINGEN',
#  'ADVIESAANVRAAG_AFDELING_ADVISERING_RAAD_VAN_STATE',
#  'ADVIES_AAN_PRESIDIUM',
#  'ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE',
#  'ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT',
#  'ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS',
#  'ADVIES_COMMISSIE',
#  'ADVIES_VAN_ANDERE_ADVIESORGANEN',
#  'AGENDA_PLENAIRE_VERGADERING',
#  'AGENDA_PROCEDUREVERGADERING',
#  'AMENDEMENT',
#  'AMENDEMENT_GEWIJZIGD_NADER_VERVANGEND',
#  'ANTWOORD_SCHRIFTELIJKE_VRAGEN',
#  'ANTWOORD_SCHRIFTELIJKE_VRAGEN_NADER',
#  'BEGROTINGSTOELICHTING',
#  'BESLUITENLIJST_PROCEDUREVERGADERING',
#  'BIJGEWERKTE_TEKST',
#  'BIJLAGE',
#  'BRIEF_AFDELING_ADVISERING_RAAD_VAN_STATE',
#  'BRIEF_ALGEMENE_REKENKAMER',
#  'BRIEF_COMMISSIE',
#  'BRIEF_COMMISSIE_AAN_BEWINDSPERSOON',
#  'BRIEF_CTIVD',
#  'BRIEF_EERSTE_KAMER',
#  'BRIEF_EUROPESE_COMMISSIE',
#  'BRIEF_FORMATEUR',
#  'BRIEF_INFORMATEUR',
#  'BRIEF_KAMER',
#  'BRIEF_LID__FRACTIE',
#  'BRIEF_NATIONALE_OMBUDSMAN',
#  'BRIEF_PRESIDENT_HOGE_RAAD',
#  'BRIEF_PRESIDIUM',
#  'BRIEF_REGERING',
#  'BRIEF_VERKENNER',
#  'BRIEF_VOORZITTER',
#  'CONVOCATIE_COMMISSIEACTIVITEIT',
#  'CONVOCATIE_INBRENG',
#  'EINDTEKST',
#  'EU_VOORSTEL',
#  'GELEIDENDE_BRIEF',
#  'GROENBOEKWITBOEK',
#  'INBRENG_VERSLAG_SCHRIFTELIJK_OVERLEG',
#  'INITIATIEFNOTA',
#  'INTERPELLATIEVRAGEN',
#  'JAARVERSLAG',
#  'KONINKLIJKE_BOODSCHAP',
#  'LIJST_MET_EU_VOORSTELLEN',
#  'LIJST_VAN_INGEKOMEN_STUKKEN',
#  'LIJST_VAN_VRAGEN',
#  'LIJST_VAN_VRAGEN_EN_ANTWOORDEN',
#  'MEDEDELING',
#  'MEDEDELING_UITSTEL_ANTWOORD',
#  'MEMORIE_VAN_TOELICHTING',
#  'MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL',
#  'MONDELINGE_VRAGEN',
#  'MOTIE',
#  'MOTIE_GEWIJZIGDNADER',
#  'NADER_RAPPORT',
#  'NOTA',
#  'NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG',
#  'NOTA_VAN_VERBETERING',
#  'NOTA_VAN_WIJZIGING',
#  'NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL',
#  'ONDERZOEKSVOORSTEL',
#  'OORSPRONKELIJKE_TEKST',
#  'OVERIG',
#  'POSITION_PAPER',
#  'RAMING_VAN_DE_UITGAVEN',
#  'RAPPORT',
#  'RAPPORT_ALGEMENE_REKENKAMER',
#  'REACTIE_INITIATIEFNEMERS',
#  'SCHRIFTELIJKE_VRAGEN',
#  'SPREKERSLIJST',
#  'STEMMINGSLIJST',
#  'STEMMINGSUITSLAGEN',
#  'STENOGRAM',
#  'VERSLAG_COMMISSIE_VERZOEKSCHRIFTEN_EN_DE_BURGERINITIATIEVEN',
#  'VERSLAG_HOUDENDE_EEN_LIJST_VAN_VRAGEN_EN_ANTWOORDEN',
#  'VERSLAG_INITIATIEFWETSVOORSTEL_NADER',
#  'VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG',
#  'VERSLAG_VAN_EEN_BIJEENKOMST',
#  'VERSLAG_VAN_EEN_COMMISSIEDEBAT',
#  'VERSLAG_VAN_EEN_HOORZITTING__RONDETAFELGESPREK',
#  'VERSLAG_VAN_EEN_NOTAOVERLEG',
#  'VERSLAG_VAN_EEN_POLITIEKE_DIALOOG',
#  'VERSLAG_VAN_EEN_RAPPORTEUR',
#  'VERSLAG_VAN_EEN_SCHRIFTELIJK_OVERLEG',
#  'VERSLAG_VAN_EEN_WERKBEZOEK',
#  'VERSLAG_VAN_EEN_WETGEVINGSOVERLEG',
#  'VOORDRACHT',
#  'VOORLICHTING_AFDELING_ADVISERING_RAAD_VAN_STATE',
#  'VOORSTEL_TOT_WIJZIGING_REGLEMENT_VAN_ORDE',
#  'VOORSTEL_VAN_WET',
#  'VOORSTEL_VAN_WET_INITIATIEFVOORSTEL',
#  'VOORSTEL_VAN_WET_TWEEDE_LEZING',
#  'WETENSCHAPPELIJKE_FACTSHEET',
#  'WIJZIGINGEN_VOORGESTELD_DOOR_DE_REGERING']

# %%
# ...so let's fetch all of that specific documentsoort
# (Note: There is a different take on doing this in part 3, but this one is easier and faster if you only care about the PDFs)

document_filter = Document.create_filter()
document_filter.filter_soort( DocumentSoort.VERSLAG_VAN_EEN_COMMISSIEDEBAT )
commissiedebatverslagen = api.get_documenten( document_filter )

len(commissiedebatverslagen) # 800ish in two seconds, much better
# Out:
# 858

# %%
commissieverslag_documenten = wetsuite.helpers.localdata.LocalKV('commissieverslag_documenten.db', str, bytes) # store the PDFs in here

for verslag in commissiedebatverslagen:
    print( verslag.titel ) # turns out the titles aren't very indicative of the document content,
    print( verslag.bestand_url )

    wetsuite.helpers.localdata.cached_fetch( commissieverslag_documenten, verslag.bestand_url )
# Out:
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6aad0a05-72e9-4670-9b53-0b3eab523a88)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a64e0e2d-316f-4233-9451-2764baa70305)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a84d9ea7-6a67-45fc-aa80-9e862ea3ea43)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0dba8510-b96d-4938-9e07-25c74316a607)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(622f1fe5-2c95-42e0-a009-76aa58b104f8)/TK.DA.GGM.OData.Resource()
# Defensieraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2ad1dfd1-619b-4739-a154-f35a72f08fc0)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1536f672-5139-423e-88da-56146f627ced)/TK.DA.GGM.OData.Resource()
# Staat van de Europese Unie 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(520cda16-e783-4cc3-bcd4-5af9c08a4405)/TK.DA.GGM.OData.Resource()
# Infectieziektenbestrijding
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2704d88c-4b9a-42d3-87f4-353d0f8220b6)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d417236d-46eb-4082-ad2e-fee237494943)/TK.DA.GGM.OData.Resource()
# Maatregelen verkeersveiligheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d0cb1d5c-babe-4fe6-8c43-045388b99ace)/TK.DA.GGM.OData.Resource()
# Verwerking en bescherming persoonsgegevens
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3519cf1c-d12e-4a8d-a383-0492ff19e104)/TK.DA.GGM.OData.Resource()
# Openbaar vervoer
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(40fafc1a-dcec-4ffe-8e68-0f42175f43ab)/TK.DA.GGM.OData.Resource()
# Defensieraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(386c2c30-df8a-489e-bff8-eb626d88d9f9)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d40907b9-3987-49e7-a0c6-b0244a43bb5d)/TK.DA.GGM.OData.Resource()
# Raad voor de Werkgelegenheid, Sociaal Beleid, Volksgezondheid en Consumentenzaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(636d5a5c-f0da-4c54-bb88-5af2f2db8e87)/TK.DA.GGM.OData.Resource()
# Raad voor de Werkgelegenheid, Sociaal Beleid, Volksgezondheid en Consumentenzaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1c87ade8-2b65-4d5d-8997-a933060fc8a1)/TK.DA.GGM.OData.Resource()
# Frequentiebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b9c04f4e-3563-4bae-89fb-509afcc59f30)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5a1fbe5f-a517-4bbc-96a6-905570a9d9c1)/TK.DA.GGM.OData.Resource()
# NAVO
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf99cace-c012-436e-a904-a7ccbcf15a7a)/TK.DA.GGM.OData.Resource()
# Raad voor Concurrentievermogen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c148cdc7-0e87-49d3-b257-c0c3dafb69d5)/TK.DA.GGM.OData.Resource()
# Investeren in Perspectief - Goed voor de Wereld, Goed voor Nederland
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4c5a2392-5ddd-414c-a17f-c13161688d02)/TK.DA.GGM.OData.Resource()
# Mensenhandel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9e900b68-cfc1-4f1c-bfb3-16e95cb55521)/TK.DA.GGM.OData.Resource()
# Rechtsbijstand
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a397fb19-78a1-4972-a7cc-5976fe039ce4)/TK.DA.GGM.OData.Resource()
# Noodpakket banen en economie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(912883d6-e35d-4e32-8a44-8434ffb2b189)/TK.DA.GGM.OData.Resource()
# Spoor: vervoer- en beheerplan
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b2d5c7f3-3fc5-4664-aec4-35c029e7fdad)/TK.DA.GGM.OData.Resource()
# Veiligheidsregio's
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7a392873-b717-43b0-a938-76ca945af0a3)/TK.DA.GGM.OData.Resource()
# Grondstoffenvoorzieningszekerheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4fa004c1-f2fd-4b00-a165-81563ce9d922)/TK.DA.GGM.OData.Resource()
# Betrekkingen tussen de Europese Unie en het Verenigd Koninkrijk
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3afff891-3963-46ed-a821-1709101abd23)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(911e0564-c464-4e1c-91b7-e17ba65c3136)/TK.DA.GGM.OData.Resource()
# Wijziging van het voorstel van wet tot samenvoeging van de gemeenten Boxmeer, Cuijk, Mill en Sint Hubert en Sint Anthonis
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cfc86bbf-8596-4e1f-8539-d8432ee736e1)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Defensie (X) voor het jaar 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1a620160-fd77-479d-a293-1831cf39eae9)/TK.DA.GGM.OData.Resource()
# Herstel van de voorzieningen in het bestuur van het openbaar lichaam Sint Eustatius (Wet herstel voorzieningen Sint Eustatius)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fbf55c76-1a3a-468c-9722-89a35fa0937a)/TK.DA.GGM.OData.Resource()
# Zee- en binnenvaart
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6976fbe4-e2e1-4264-b767-b6440c7cac61)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Defensie (X) voor het jaar 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(51f6828d-2f2f-447a-b92c-b7b310a36e48)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5c9c2339-7459-4096-8ed7-157c58c66b96)/TK.DA.GGM.OData.Resource()
# Raad voor Vervoer, Telecommunicatie en Energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(245c43b1-f54f-479a-9db7-73a7e2a63eec)/TK.DA.GGM.OData.Resource()
# Drugbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e9ff479d-091b-4c66-8add-7980e381007c)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5250ffa6-ba33-4599-aa50-be1c777f2a3d)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f92a4871-ff01-45b5-ad88-39474fc6700f)/TK.DA.GGM.OData.Resource()
# NAVO
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f9316317-07ce-4ffd-9e3f-4e10e430f43d)/TK.DA.GGM.OData.Resource()
# Srebrenica
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5ac16482-b98b-410e-bbf4-b86b527f608b)/TK.DA.GGM.OData.Resource()
# Adoptie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bc905868-e1e2-49c5-81d5-427c935abf4f)/TK.DA.GGM.OData.Resource()
# Bedrijfslevenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a10e9120-e6dd-4ca4-9eaf-d8b38bc86913)/TK.DA.GGM.OData.Resource()
# Toezichtsverslagen AIVD en MIVD
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bd64ba65-abed-49dd-9638-e5468bd12d20)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(56a688a9-e0bf-47c5-b2b9-0036c1aa3a4f)/TK.DA.GGM.OData.Resource()
# Handhaving milieuwetgeving
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1816cafe-812f-45ad-99cb-787cc7c605d4)/TK.DA.GGM.OData.Resource()
# Invoering Diagnose Behandeling Combinaties (DBCs)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b67ea60c-b4f9-4dce-8e2a-87e9f917feb1)/TK.DA.GGM.OData.Resource()
# Waterbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(488d6721-a60c-4194-90c4-f3d29cef30a6)/TK.DA.GGM.OData.Resource()
# Politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5b434e2e-6257-4d42-9664-3d07292b404e)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5d4ec04c-5a62-4e0a-9c0d-95b3ab646420)/TK.DA.GGM.OData.Resource()
# Wet- en regelgeving financiële markten
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(00011813-1ac7-48b0-93e6-7fab59345d0f)/TK.DA.GGM.OData.Resource()
# Problematiek rondom stikstof en PFAS
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6e8ae6c5-0285-40dd-8274-8bdcfdb35694)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaat van het Infrastructuurfonds voor het jaar 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6c45712a-fa30-48d8-a329-3c54eca40f44)/TK.DA.GGM.OData.Resource()
# Prestaties in de strafrechtketen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0a9f9792-41fa-4836-b5b1-688559969bd1)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(890e02e2-0358-43ed-8f7d-407a432aac10)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b3abccc4-afe2-4f89-8835-bf2054b15b92)/TK.DA.GGM.OData.Resource()
# Geneesmiddelenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a9e47b2b-02bf-4eef-aee7-2b73ccd67c40)/TK.DA.GGM.OData.Resource()
# Vliegramp MH17
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(78c6f4ec-7cdb-4111-bd10-cd28fa4cd1c5)/TK.DA.GGM.OData.Resource()
# Wijziging van de Tijdelijke wet Groningen in verband met de versterking van gebouwen in de provincie Groningen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(08b66da0-b7ee-4a9a-aa89-3966556b5b6e)/TK.DA.GGM.OData.Resource()
# Bedrijfslevenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(26ef6d08-d76c-4e2e-9349-8db7f8dcac22)/TK.DA.GGM.OData.Resource()
# Jeugdzorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2d5e576e-c61f-4c29-bb37-51c707b3bc99)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f60fc8cf-535f-45fb-9038-54475df409c2)/TK.DA.GGM.OData.Resource()
# Landbouw- en Visserijraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(50419bf3-e9ae-49e3-aa7f-771301366690)/TK.DA.GGM.OData.Resource()
# Langdurige zorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dc6ae2ae-dd89-4777-aa79-9335f2c48fe7)/TK.DA.GGM.OData.Resource()
# Verbetering verantwoording en begroting
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2eead8f2-65a9-4555-82b7-acf894369337)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Defensie (X) voor het jaar 2021
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(17ee23bd-7eca-487a-aee7-c962c90ea29f)/TK.DA.GGM.OData.Resource()
# Luchtvaartbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0b28fbe0-ca68-4614-afa7-8b051f2b5b49)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(88ef9158-f43e-431e-b3e4-1e730d49b292)/TK.DA.GGM.OData.Resource()
# Integratiebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d7942ed-45bb-48d0-a85c-660cf3967158)/TK.DA.GGM.OData.Resource()
# Arbeidsomstandigheden
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c5424cb0-f628-412f-a4b0-dbc0f156f773)/TK.DA.GGM.OData.Resource()
# Toekomstig sportbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3fda2c67-8c8b-4c65-9267-b6a5dd809e70)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(67442e95-87e6-4387-bb01-f80fc0024937)/TK.DA.GGM.OData.Resource()
# Structuur van de uitvoering werk en inkomen (SUWI)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c6f13958-1710-4845-9f24-4480e506f542)/TK.DA.GGM.OData.Resource()
# Rassendiscriminatie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(acf9b2b8-9c29-4b68-b9a7-75722507da11)/TK.DA.GGM.OData.Resource()
# Herziening Zorgstelsel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1cb41d1d-7d79-4d3e-8268-14e9072e58d2)/TK.DA.GGM.OData.Resource()
# Zee- en kustvisserij
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ec3789df-e41a-4a26-a755-173150b95dde)/TK.DA.GGM.OData.Resource()
# Handhaving milieuwetgeving
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9669e8b1-1641-441f-898c-327757399bf8)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(74896ae6-e0b6-49e3-84c4-520f38be2232)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ce6eb4cd-1462-4c24-9503-639c2f077ad0)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4ca29b39-062c-48fd-a8fa-85f0bc601b96)/TK.DA.GGM.OData.Resource()
# Dierenwelzijn
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(46dcc5bd-88b3-4a27-8a5a-ae108f340269)/TK.DA.GGM.OData.Resource()
# Gaswinning
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(234c0536-6f8e-436c-b7d6-f63bf2a80eef)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(77d7f569-0e36-43d2-a1aa-a59786df046b)/TK.DA.GGM.OData.Resource()
# Arbeidsmigratie en sociale zekerheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b822d7c5-0eca-49de-80c6-fcd1c871e68b)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ac0dcdd4-e902-411b-948a-5731d4a14d89)/TK.DA.GGM.OData.Resource()
# Noodpakket banen en economie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(86a99d3a-796a-4e49-9750-1391c116a108)/TK.DA.GGM.OData.Resource()
# Luchtvaartbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e1f369b0-fdbd-4887-bc7d-340bebce2b55)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(76f82342-dd0b-4a2c-a322-37c55aebbdf7)/TK.DA.GGM.OData.Resource()
# Bestrijden witwassen en terrorismefinanciering
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2cd10d5a-d37a-4cc4-afe4-b3a3c3973d5d)/TK.DA.GGM.OData.Resource()
# Algemene Vergadering der Verenigde Naties
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2538d467-733c-411c-a2a0-7956edca6a13)/TK.DA.GGM.OData.Resource()
# Beleidsdoorlichting Infrastructuur en Waterstaat
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(327ab07a-9bae-4a09-b6d0-d3da195b4312)/TK.DA.GGM.OData.Resource()
# Gaswinning
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(af0b1c2a-9e7b-43a2-8d06-f74721d3f62b)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eb7a6965-43c7-42bb-bfb1-6a223ddfa939)/TK.DA.GGM.OData.Resource()
# Maatregelen verkeersveiligheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(43c4696c-8eef-4da4-af72-e27e731b8b95)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a95fcdc0-551b-415f-bf58-de546feefc38)/TK.DA.GGM.OData.Resource()
# Kindermishandeling
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b1bc37f0-6385-4986-a666-0c4d6cbf1f25)/TK.DA.GGM.OData.Resource()
# Arbeidsmarktbeleid en opleidingen zorgsector
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4b1111df-c54a-48e3-b3df-b15236a077f2)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9157b109-695d-4d16-b2b4-e079e2318429)/TK.DA.GGM.OData.Resource()
# Mestbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(49f8419f-b000-4b1e-b28e-31e8783fc67d)/TK.DA.GGM.OData.Resource()
# Internationaal fiscaal (verdrags)beleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3a7afb50-7d3d-4b01-aaf1-6afe23758645)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7f866c53-e5a3-4408-9ef8-4703a8cebbc6)/TK.DA.GGM.OData.Resource()
# Herziening van het Gemeenschappelijk Landbouwbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(170e82a7-9ff3-4f88-b06f-f3ead8339a1e)/TK.DA.GGM.OData.Resource()
# Werken in het onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(766b4c5e-0597-4396-9205-01795527fdc0)/TK.DA.GGM.OData.Resource()
# JBZ-Raad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6006f1b0-6e4a-46af-9f70-1395b65fd835)/TK.DA.GGM.OData.Resource()
# Toekomst mediabeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(73ccb588-5222-4941-9689-c84a7bf25e53)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cf46a277-3ab2-4033-9a54-59d0a64ccefe)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(47c134af-7b35-4c63-bb22-e066809af82e)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(573b34ee-d303-42b4-aa8a-0b6eb6fad23b)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0f6a6f61-a65a-49ef-8c89-0d41e3e7a02e)/TK.DA.GGM.OData.Resource()
# Nederlandse deelname aan vredesmissies
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cd66e004-5e04-49c5-a696-53b375d1badc)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e1c89f55-a47a-4255-b527-d057cd47eb56)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cd72f8f8-d279-4690-9adc-860fd6e304c1)/TK.DA.GGM.OData.Resource()
# Nederlandse diplomatie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(006647bf-902e-4368-8c0b-dd551fbbe0ee)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a286183f-a71a-4a35-8972-17973dcef6d3)/TK.DA.GGM.OData.Resource()
# Wapenexportbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d2f33043-b51a-451c-a5ac-2aed2a74b135)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Justitie en Veiligheid (VI) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(70ac4a4d-82b1-4343-85f6-551f99a7fcc9)/TK.DA.GGM.OData.Resource()
# Politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4fff3d03-c38f-4166-bda3-e433dc585ef3)/TK.DA.GGM.OData.Resource()
# Geestelijke gezondheidszorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(66052e4c-7665-4752-b0b2-25230684d9ec)/TK.DA.GGM.OData.Resource()
# Renovatie Binnenhof
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dcbfa5b3-a93b-4d0a-a5dd-21267d0b0576)/TK.DA.GGM.OData.Resource()
# Raad voor Vervoer, Telecommunicatie en Energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e457b457-56a3-4788-bcb3-7806dd6b8f16)/TK.DA.GGM.OData.Resource()
# China
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(82ed82b7-2f93-484b-a091-bb94106f1f3b)/TK.DA.GGM.OData.Resource()
# Zee- en binnenvaart
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a7a94995-5ef8-4f07-bbb1-dd491b15f67c)/TK.DA.GGM.OData.Resource()
# Betalingsverkeer
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(468b1d00-3439-4c09-b50b-470c780f121c)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(aa7d5095-a923-4116-98b5-91239ceeb4c1)/TK.DA.GGM.OData.Resource()
# Naar een veiliger samenleving
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4620ffff-b8e0-4238-823c-9497f1131f39)/TK.DA.GGM.OData.Resource()
# Bouwregelgeving
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0d12fab6-0bbb-4426-bb0d-c4c2749c4f38)/TK.DA.GGM.OData.Resource()
# Verkiezingen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3c68dd48-3fc1-4ac2-858a-88035d5f60b4)/TK.DA.GGM.OData.Resource()
# Raad voor Concurrentievermogen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b5fee092-42ef-4a3b-9a7c-e1e683a8c6b8)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a6e3a044-8981-4348-b4ec-3837fa06d58a)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2c91f95d-fb35-4041-9a8e-4d95c3a9fcff)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c70f5939-b370-43f7-9481-2b136214dcc9)/TK.DA.GGM.OData.Resource()
# NAVO
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(17b1dea0-f1e7-4fe2-9490-7438c576ba1f)/TK.DA.GGM.OData.Resource()
# Grondstoffenvoorzieningszekerheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3cbebc9d-f94e-4c2c-99b7-b9f6dbbc5640)/TK.DA.GGM.OData.Resource()
# Raad voor Vervoer, Telecommunicatie en Energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(99c98180-4f4f-43fb-9ac1-d1bc95c3680a)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(07eaaeab-a36b-4b41-9bfb-fcf25b12d37c)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(773535af-d076-4b20-9122-2a9e10bfd229)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(198a00ac-19ce-4c65-bd98-c773812bd37b)/TK.DA.GGM.OData.Resource()
# Primair Onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4f8a1310-6d94-4fc0-b48c-1cf04668d0f3)/TK.DA.GGM.OData.Resource()
# Verwerking en bescherming persoonsgegevens
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ee0fc666-7e0d-42ad-9619-d1ad99a49e25)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(df825e23-961e-41ee-9108-f53bb729f390)/TK.DA.GGM.OData.Resource()
# Maatregelen verkeersveiligheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f5f0e717-9e86-471c-a7d0-13d6e3580bb5)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f2d57303-e138-496f-ad5b-1f1224d15428)/TK.DA.GGM.OData.Resource()
# JBZ-Raad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ed929c7b-6d81-4169-8d44-29e1111ec85e)/TK.DA.GGM.OData.Resource()
# Milieuraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39f6e2b0-ba62-4cfb-b7a2-383280788869)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e116e08f-d946-465a-94d6-550ba52841f3)/TK.DA.GGM.OData.Resource()
# Herziening van het Gemeenschappelijk Landbouwbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(adc33fc2-7222-4be4-873f-8b4457eaaf97)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c3b49bdc-ef25-43e5-954b-5888f2d77e64)/TK.DA.GGM.OData.Resource()
# Gaswinning
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f64fefa-439d-4e48-be92-5db14bd701e1)/TK.DA.GGM.OData.Resource()
# Justitiële Inrichtingen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(80afbdc9-f10e-430c-afe8-8aa8a3c437bb)/TK.DA.GGM.OData.Resource()
# Investeren in Perspectief - Goed voor de Wereld, Goed voor Nederland
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0305ee0b-b0ae-40b4-8bbd-977fe1dd49f0)/TK.DA.GGM.OData.Resource()
# Maatschappelijk verantwoord ondernemen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6939cc2b-2d8c-4ffb-806d-c745d240353d)/TK.DA.GGM.OData.Resource()
# Kansspelen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(96b4f242-b669-4bcc-87e2-1fad192f0704)/TK.DA.GGM.OData.Resource()
# Maatschappelijk verantwoord ondernemen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(36b09350-667c-4359-8b82-972d7601a95d)/TK.DA.GGM.OData.Resource()
# Fraudebestrijding in de zorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cf12df46-4eec-4a6d-9f46-0cc520f24e0c)/TK.DA.GGM.OData.Resource()
# Voortgezet Onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a5aeeadb-4eed-4e7e-86c9-2afd8fdd3dcc)/TK.DA.GGM.OData.Resource()
# Waddenzeebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e7b55a4a-8edd-442d-a1c3-94be6015b5d7)/TK.DA.GGM.OData.Resource()
# Defensieraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ef97a0ba-5043-4a80-94f3-bff8aa07e7d4)/TK.DA.GGM.OData.Resource()
# Terrorismebestrijding
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a3e4d912-0401-49c6-a752-905ecf367cea)/TK.DA.GGM.OData.Resource()
# Gezondheid en milieu
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3951b7f6-b6c0-4b52-bd8e-bbba3ebcec3f)/TK.DA.GGM.OData.Resource()
# Raad voor de Werkgelegenheid, Sociaal Beleid, Volksgezondheid en Consumentenzaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e9b1749d-62aa-4fa1-ac04-728439b1c391)/TK.DA.GGM.OData.Resource()
# Nieuwe Commissievoorstellen en initiatieven van de lidstaten van de Europese Unie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5ec74d97-88be-4ff4-bf82-df5e496c2f17)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Binnenlandse Zaken en Koninkrijksrelaties (VII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b29df75-e1a5-401c-85cf-f6b20e330e6a)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Binnenlandse Zaken en Koninkrijksrelaties (VII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3ced3333-70e0-4c41-a328-3d86be9d9a08)/TK.DA.GGM.OData.Resource()
# Deelnemingenbeleid Rijksoverheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(802befdd-4a74-4241-8f16-7fb1b8bf65bc)/TK.DA.GGM.OData.Resource()
# Bestrijding georganiseerde criminaliteit
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5053a98b-b8bb-485c-955c-a355fca5a27f)/TK.DA.GGM.OData.Resource()
# Verwerking en bescherming persoonsgegevens
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8c520bb0-d1ec-41bf-9d0b-02aaca38cb34)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d0d99004-136c-499b-bb97-b6af6e0d8af9)/TK.DA.GGM.OData.Resource()
# (Glas)tuinbouw
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e8c4280c-a4ca-4c63-9af3-a8b60c19f6ee)/TK.DA.GGM.OData.Resource()
# Hoger Onderwijs-, Onderzoek- en Wetenschapsbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(baf41678-27b1-4e7e-88e0-f31662aada05)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2641cc20-9988-4f00-aec3-c1091634bfa8)/TK.DA.GGM.OData.Resource()
# Dierenwelzijn
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bff785c2-2a54-4993-bcdb-a482311ec64f)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(676ac700-73ba-4d5f-90dc-799853c72b8a)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Economische Zaken en Klimaat (XIII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d769f084-2ed4-4a4a-8723-cb1aeaeeb4ad)/TK.DA.GGM.OData.Resource()
# Natuurbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(346fd748-70f6-483c-80fb-4d3ccbe02ac5)/TK.DA.GGM.OData.Resource()
# EU-voorstel: Verordening betreffende transparantie en gerichte politieke reclame COM (2021) 731
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(858ff698-35e5-4fd5-9083-a509fcaa4c5f)/TK.DA.GGM.OData.Resource()
# Nieuwe Commissievoorstellen en initiatieven van de lidstaten van de Europese Unie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(67218c2f-053a-49c9-bf87-dbab77f7d733)/TK.DA.GGM.OData.Resource()
# Investeren in Perspectief - Goed voor de Wereld, Goed voor Nederland
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f4cd0633-fbec-4df1-acbd-39a0f4bd7acd)/TK.DA.GGM.OData.Resource()
# NAVO
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(859eec70-a87b-4d23-8fb4-c049b2768207)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(676e427a-4892-4a3e-add6-c3b93ec92dea)/TK.DA.GGM.OData.Resource()
# Landbouw- en Visserijraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3a3ec5b5-94cb-456f-836e-dd57ed3e70a0)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(67a1ec01-e3d4-4187-8801-9d0a51870309)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Infrastructuur en Waterstaat (XII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b79dac0-ccf4-44be-9b00-6a6abac99f9b)/TK.DA.GGM.OData.Resource()
# Kwaliteit van zorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a1c53bd0-87d7-4f43-a84e-71ed34e581b7)/TK.DA.GGM.OData.Resource()
# Voorzienings- en leveringszekerheid energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(64cb7a4a-ac53-4498-b1cf-a47c9407819e)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c46d9a93-216a-483e-aa9d-ef403caa91c5)/TK.DA.GGM.OData.Resource()
# Politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c0d9d266-f917-4bcd-a07a-274087e1d36c)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Economische Zaken en Klimaat (XIII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(31668cfe-6ff7-442f-967e-4685e5851b52)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Defensie (X) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c2c3405e-c72b-449a-a4fe-dcf6d55083b0)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Sociale Zaken en Werkgelegenheid (XV) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(20f2a214-f158-47c2-ae73-e6ecc4270265)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaat van het Ministerie van Financiën (IXB) en de begrotingsstaat van Nationale Schuld (IXA) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(436e7e23-7493-4fcb-b3c9-09ea22ef2b93)/TK.DA.GGM.OData.Resource()
# Rechtspositie van politieke ambtsdragers
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a4677bde-65d4-4641-9753-7d869c8d0700)/TK.DA.GGM.OData.Resource()
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b8543c5e-6e80-4d60-8fa5-b91adc8aaba4)/TK.DA.GGM.OData.Resource()
# Uitvoering en evaluatie Participatiewet
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4dfab56c-6d3d-4d3a-a563-525ee3abed3c)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(19915865-fdea-46ff-9bc2-82345c9f385b)/TK.DA.GGM.OData.Resource()
# Luchtvaartbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b03f8ae-550b-4ccc-b9ac-d5aec113308b)/TK.DA.GGM.OData.Resource()
# Mensenhandel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(13e106c2-8987-4a47-a839-f4bdbddb569f)/TK.DA.GGM.OData.Resource()
# Rassendiscriminatie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a0355058-9fd6-46a2-96b5-f1c8170efb3c)/TK.DA.GGM.OData.Resource()
# Milieuraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8564fe9a-5c16-42a1-9acd-14e8015803d6)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Volksgezondheid, Welzijn en Sport (XVI) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f53a213c-9aee-4be0-88b9-8f1e0d69a2a4)/TK.DA.GGM.OData.Resource()
# Vreemdelingenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1ad8a8dc-0ece-4791-ae0a-52ec65024e7c)/TK.DA.GGM.OData.Resource()
# Nieuwe Commissievoorstellen en initiatieven van de lidstaten van de Europese Unie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(811ed247-abe2-4365-bdc9-736fe37480cc)/TK.DA.GGM.OData.Resource()
# Douane
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(558ad291-d63a-464c-b140-9046f81aa3e9)/TK.DA.GGM.OData.Resource()
# Personen- en familierecht
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(37fd3884-e498-4935-b1f7-fb84b5b8fc6b)/TK.DA.GGM.OData.Resource()
# Veiligheid op school
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(98485deb-252f-4c95-a266-0a52dc5240a7)/TK.DA.GGM.OData.Resource()
# Noodpakket banen en economie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(32aacd95-fd27-4a32-ac2d-1b457778d5f7)/TK.DA.GGM.OData.Resource()
# Integriteitsbeleid openbaar bestuur en politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(54fce211-3a0c-49bf-a01b-080e23e0a705)/TK.DA.GGM.OData.Resource()
# Problematiek rondom stikstof en PFAS
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(134893df-66cf-4bc6-89a7-7e04148693a8)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(51f47480-4ecc-4d6d-8b5f-922922f7f63c)/TK.DA.GGM.OData.Resource()
# Hulp, handel en investeringen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf43383a-4a99-474c-b2d9-2e964b91629c)/TK.DA.GGM.OData.Resource()
# Nieuwe visie cultuurbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(833a822b-f430-498d-8f2c-a4f18dffb956)/TK.DA.GGM.OData.Resource()
# Kwaliteit van zorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ea48e83f-3c85-4abb-8a06-ce45d7d9bb53)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Justitie en Veiligheid (VI) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(836f74cd-6fc1-477e-8ee2-5c5b098ea7ad)/TK.DA.GGM.OData.Resource()
# Defensieraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(89952c3d-0806-4a5d-b416-825cb2a534a1)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ef17951c-3c0f-428e-8a0c-5127c0617c24)/TK.DA.GGM.OData.Resource()
# Justitiële Inrichtingen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f8910d2f-2a6b-4162-9d20-e6f1060f55e3)/TK.DA.GGM.OData.Resource()
# Omgevingsrecht
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(10106a03-2a7c-4e84-b772-e7a9636d505e)/TK.DA.GGM.OData.Resource()
# Landbouw- en Visserijraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8efb8184-8170-47bf-a3ac-e9a41d09d399)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1fa310b6-f972-4fb5-be4c-0162417895ae)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ea21ea1a-5b2d-49bf-b08d-673d5e1b7fa9)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Defensie (X) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f8e3dbce-e062-4711-90f9-a9e91a705c31)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(86a2bbcc-b841-4b9d-ab1f-0dc822ce81a8)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f152b99-a5ef-459e-a2e6-5693b124b25d)/TK.DA.GGM.OData.Resource()
# Voorzienings- en leveringszekerheid energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c889af86-f299-4237-b38e-b1a7e37cecf7)/TK.DA.GGM.OData.Resource()
# Preventie en bestrijding van stille armoede en sociale uitsluiting
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e5b63521-b1a9-4e0f-8785-ce9551b6fb4a)/TK.DA.GGM.OData.Resource()
# JBZ-Raad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f48bd55f-c94d-4924-a6e6-6b33fccd1682)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0386bc1f-9fe2-48b4-9983-ee6c7b15bb23)/TK.DA.GGM.OData.Resource()
# Aanpak regeldruk en administratieve lasten
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d2c569ea-53a3-4a3a-979f-80fe336568aa)/TK.DA.GGM.OData.Resource()
# Stimulering duurzame energieproductie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a5729adf-5f6b-4766-b499-aae6ced529da)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(76ddd41b-7822-4a75-8197-ed375a2626ca)/TK.DA.GGM.OData.Resource()
# Veiligheidsregio's
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39a6a22e-0cdd-4eb5-9038-e656314798f1)/TK.DA.GGM.OData.Resource()
# Wijziging van enkele belastingwetten en enige andere wetten (Belastingplan 2022)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e213793a-cfbd-49ce-bce5-2f9e8f6c9160)/TK.DA.GGM.OData.Resource()
# Raad voor Vervoer, Telecommunicatie en Energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(60f12548-39e1-49ed-b690-e6c6fccdea8d)/TK.DA.GGM.OData.Resource()
# Wijziging van de Wet op het financieel toezicht houdende nadere regels met betrekking tot het beloningsbeleid van financiële ondernemingen (Wet nadere beloningsmaatregelen financiële ondernemingen)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3882b8e5-a420-4e32-b558-3170419ffab7)/TK.DA.GGM.OData.Resource()
# Preventief gezondheidsbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(af00a4bf-816e-4304-8528-77d321016a26)/TK.DA.GGM.OData.Resource()
# Situatie in de Oekraïne
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d733d8e3-e49f-4e0d-b9e2-0a51624bf89c)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(41c83bcc-3431-4dff-8f10-a20740074516)/TK.DA.GGM.OData.Resource()
# Passend onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(73ba286e-0e3b-4a52-a7c5-bcfb5576fd84)/TK.DA.GGM.OData.Resource()
# Gaswinning
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8a07ec87-76f4-4b3e-a124-53cfde39a6b6)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7191e7fa-5c71-4f15-9c36-0ecc13bfc307)/TK.DA.GGM.OData.Resource()
# Mobiliteitsbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a5eb26ec-e4ed-4b3b-b620-623a4d40e13b)/TK.DA.GGM.OData.Resource()
# Evaluatie Wet toezicht accountantsorganisaties (Wta)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7e199e92-8a87-4fd9-9ece-f93551982eb3)/TK.DA.GGM.OData.Resource()
# Toekomst pensioenstelsel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a6ad6581-cb26-49b0-bb4f-2681d90b5154)/TK.DA.GGM.OData.Resource()
# Seksuele intimidatie en geweld
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(654c0d1a-f18d-4b8c-93d1-a92598ddfb4f)/TK.DA.GGM.OData.Resource()
# Primair Onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1835fb61-c28d-4127-a684-b90dba02fb6b)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(980418a5-fab2-469d-9ccd-e02b9a1ff13d)/TK.DA.GGM.OData.Resource()
# Structuur van de uitvoering werk en inkomen (SUWI)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4b7d054d-6682-4fe3-b3a3-049bb59653ee)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(caac937f-7371-4ceb-aa99-8c68f2cd8ad3)/TK.DA.GGM.OData.Resource()
# Duurzame ontwikkeling en beleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5be27f79-b09c-4020-9c69-957091190890)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(479d2a31-ee9d-4124-aac0-b01e819d4403)/TK.DA.GGM.OData.Resource()
# Bedrijfslevenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c34f2bfb-94ec-45f5-8cf8-e52339797c48)/TK.DA.GGM.OData.Resource()
# Luchtkwaliteit
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(90aafc25-581b-4e11-9068-18056abff18c)/TK.DA.GGM.OData.Resource()
# Industriebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(76926036-33d7-4bb7-8c68-56340e4f914b)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Binnenlandse Zaken en Koninkrijksrelaties (VII) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(45469402-3caa-458d-8650-b5237ee81fd7)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7b3a7c4d-407c-4bdb-9463-032ee209a9d0)/TK.DA.GGM.OData.Resource()
# Nieuwe Commissievoorstellen en initiatieven van de lidstaten van de Europese Unie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a47f8459-ebc1-43bb-adf3-7a3838685318)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a764fc19-ccce-42e5-a9f6-bab2e9965b41)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(09289458-37b3-49c7-b97d-03aa94dd7914)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d7f5216b-09fc-4796-a197-28d52942f630)/TK.DA.GGM.OData.Resource()
# Vergaderingen Interim Committee en Development Committee
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2c123edb-df80-4c55-b0ab-2ae89899ce9c)/TK.DA.GGM.OData.Resource()
# Handhaving milieuwetgeving
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ec9caca9-f278-4795-a4dd-4553d7765dd6)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(48db710f-eff6-46fc-aedf-a14913a77377)/TK.DA.GGM.OData.Resource()
# Arbeidsmarktbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(20b071f2-8c44-49b2-aa73-983c5420842a)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ea83f9c0-d70f-4e2a-a9d3-be0e86d19846)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c7954e77-82e9-4d0c-8074-f1780a24a495)/TK.DA.GGM.OData.Resource()
# Biodiversiteit
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0285eb87-07bb-41ea-8fbb-37e9c80cc790)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(24f190c4-231d-4635-ae99-b0b38e92c0cb)/TK.DA.GGM.OData.Resource()
# Investeren in Perspectief - Goed voor de Wereld, Goed voor Nederland
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(120299c5-d35d-44af-990b-d40e7f2e88ea)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2022
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(01a339ac-21c0-43a3-9e53-e0f41d730b8a)/TK.DA.GGM.OData.Resource()
# Maatregelen verkeersveiligheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c02d5b3b-6f8c-4090-bbfa-4533a77aeb0c)/TK.DA.GGM.OData.Resource()
# Dierenwelzijn
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5e549771-45b4-43dd-b497-54d967abd14b)/TK.DA.GGM.OData.Resource()
# Rechtsbijstand
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4e488b13-0d40-4d4e-95ce-a956c9055fae)/TK.DA.GGM.OData.Resource()
# Integratiebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cabc7d8d-2c75-4ec7-bf43-b5ada521d172)/TK.DA.GGM.OData.Resource()
# Infectieziektenbestrijding
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(942bd588-6533-48b9-a704-cdeeef02fefc)/TK.DA.GGM.OData.Resource()
# Dierproeven
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(31e68bed-f21a-4a33-973a-04288e32f8e2)/TK.DA.GGM.OData.Resource()
# Politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4b7fdaed-03f3-4c29-90e3-7bb121b4975a)/TK.DA.GGM.OData.Resource()
# Voorstel van wet van de leden Van Raak, Fokke, Koser Kaya, Voortman, Segers, Thieme en Klein houdende de oprichting van een Huis voor klokkenluiders (Wet Huis voor klokkenluiders)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6bd136df-2b55-40ad-a69d-da21e1d5a1c1)/TK.DA.GGM.OData.Resource()
# Kinderopvang
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3f509d52-22f8-4dc9-aaeb-e16fc40e6a6d)/TK.DA.GGM.OData.Resource()
# Geestelijke gezondheidszorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ac0bb1b8-8d24-403a-b606-7219ddbcbe32)/TK.DA.GGM.OData.Resource()
# Langdurige zorg
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(02376120-09b0-4482-ba19-ef134f5d58c9)/TK.DA.GGM.OData.Resource()
# Situatie in de Oekraïne
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1817817c-b61c-4827-9d45-31cad7686340)/TK.DA.GGM.OData.Resource()
# Toerisme en recreatie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(25983144-e931-4ee8-bf38-93a407edf9e2)/TK.DA.GGM.OData.Resource()
# Grondstoffenvoorzieningszekerheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c1c9daf0-762d-410e-9757-a0759b8b30c9)/TK.DA.GGM.OData.Resource()
# Herziening Belastingstelsel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7253b00e-08f2-4f2c-9dc0-ee8fa225700f)/TK.DA.GGM.OData.Resource()
# Drugbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ea37d3fe-0897-4675-92f0-0f705adb613b)/TK.DA.GGM.OData.Resource()
# Arbeidsomstandigheden
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b1db4d3-6a6f-4149-876e-51f4b1c23de3)/TK.DA.GGM.OData.Resource()
# Defensieraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(21f311bc-a082-4e02-810b-7dacad96f89a)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bb7eed21-651c-450f-9567-a7f4a770830f)/TK.DA.GGM.OData.Resource()
# Naar een veiliger samenleving
# ...
# Bestrijding internationaal terrorisme
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(94e0bcc1-85c9-4788-8a89-9e26d5990798)/TK.DA.GGM.OData.Resource()
# De situatie in het Midden-Oosten
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(50d2a337-d7db-4080-95e9-b9fb3697b6b5)/TK.DA.GGM.OData.Resource()
# Landbouw- en Visserijraad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6809c577-8754-4a6e-8772-ead56f09c9f3)/TK.DA.GGM.OData.Resource()
# Mensenhandel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0558cca6-fed9-41cf-8da4-aa9ae50a36ee)/TK.DA.GGM.OData.Resource()
# Politie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7690ce5c-4c42-449e-9ec7-27712f48a0dc)/TK.DA.GGM.OData.Resource()
# Vreemdelingenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f111ddc-a780-49d2-b63d-e88593442f18)/TK.DA.GGM.OData.Resource()
# Terrorismebestrijding
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b4b9d0fe-37ee-4e4c-9f35-a6dcef52953b)/TK.DA.GGM.OData.Resource()
# JBZ-Raad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(82b588d0-4751-4607-82ce-a9db0e5cadcf)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dd531622-5293-428d-81b8-84419bcb0d16)/TK.DA.GGM.OData.Resource()
# Voorzienings- en leveringszekerheid energie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1175f398-39fe-4d83-9a35-39e51bedf632)/TK.DA.GGM.OData.Resource()
# Gaswinning
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a7c0fa72-28ec-45e8-b678-e54c4458ce9b)/TK.DA.GGM.OData.Resource()
# Arbeidsmarktbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(82252c80-6e1e-4ed0-8e56-bfea23701231)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a2d43a1c-d3b8-484b-8717-c31ff8834337)/TK.DA.GGM.OData.Resource()
# Maatregelen verkeersveiligheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(55973cfa-2dd2-442c-a2c2-4d541b2ffe99)/TK.DA.GGM.OData.Resource()
# Mobiliteitsbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f156c348-d0b2-4b22-b1e3-816521e92157)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39c1bfc5-87bc-4b50-9cab-6c45500298e0)/TK.DA.GGM.OData.Resource()
# Preventie en bestrijding van stille armoede en sociale uitsluiting
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(748064c9-bb39-4c86-a11d-f96bbe300da9)/TK.DA.GGM.OData.Resource()
# Detailhandel
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(57147370-7587-4c19-a86a-12a7489c6d1d)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9aaf6ceb-ebfe-4274-ad1e-ca8f89e8646d)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e6998190-b819-44bf-8575-f820137b8652)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2024
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9fd44cc1-9ce8-43b8-b7df-533a098c0a91)/TK.DA.GGM.OData.Resource()
# Veiligheid van het railvervoer
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(34b81000-7b17-4a7f-beee-8d73106110a2)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dccf4ac0-e17c-42e6-a4b4-158361d509aa)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0c7c7025-bffa-4442-b153-23e06117fd4a)/TK.DA.GGM.OData.Resource()
# Zee- en binnenvaart
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(76670258-e8d6-4676-b573-67cb63f45ffb)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4339d2ba-a42c-42ac-bf85-50b5228ca314)/TK.DA.GGM.OData.Resource()
# (Glas)tuinbouw
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8a17b6ff-7600-47f7-9ff8-6d5a4559945f)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6165b9e0-95ed-4690-985c-381815a86bdd)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4b908c59-d84d-48fc-84f8-4a05160f97fd)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cb10d7c0-72d8-4bf9-a4b9-a5b56eaa77e5)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(86a762ed-a34a-4acc-b4c1-091141c65387)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(304d0358-8b88-4376-a0c2-cbb5992bf13e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(496f6ed0-5b4f-4ad9-af32-0379aab8ce30)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cc39566f-953a-45e2-bd67-09784dd1e228)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1cca1e2b-be19-4fe0-8f69-0c97027da546)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(39267431-ca6f-497c-80bf-2e441320bbc9)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(912a9d3b-ad48-4580-afb2-49697f027d92)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b79cac1a-bd3b-4c48-aae6-9808da6b8685)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dc608652-3943-4f4f-94ab-bd243809e2fe)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(85e271c9-3378-4d7b-9fa6-cc659460f9bb)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f876b9aa-bc3f-41d8-b448-04d4c7187fae)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d17e273c-c616-488f-b8e0-1854e0fb1990)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(aadff31e-f9a5-445a-8245-e78e1845174e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6327c557-b5bf-430f-8e97-ed76149f18be)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a68799b6-a0ec-49b6-9362-0088586096e1)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(514e0222-93f0-4caf-ab97-f49d0196868b)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5fe2e4c3-4f88-49a4-ab81-01a76f58bf40)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e7c542ed-b485-463f-a317-079cfcb7128d)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4a8f6c8a-2df1-41e5-a900-088d0d2f6d58)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0a39e4bd-4482-424a-981e-420494e0c962)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(970b032e-588b-4a96-9bb1-4800d355443f)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3b8d9373-cad4-4804-9abb-abf4b4c20cd1)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c5a161e8-a651-4b02-b2fb-0ad9afc7429a)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(515d7f6f-7ff1-422e-8be8-88ffb8b6a31e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(476a6d5d-5578-40c5-abb7-a5cb2c9e3882)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d0f970fa-1508-4f54-a10e-b3359d4e3b8a)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(22469d1a-4b5f-4dc7-be3b-c00363fa7c10)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2024
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(750caca9-939a-447b-aae6-090af4a86d0a)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4079fa8f-23bb-4ad2-a8db-1d152d854d2f)/TK.DA.GGM.OData.Resource()
# Kabinetsaanpak Klimaatbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3df08cfe-c336-468f-9612-63150bf9f5e9)/TK.DA.GGM.OData.Resource()
# Justitiële Inrichtingen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(41e74a28-440f-44cb-a037-1d3646ea75e0)/TK.DA.GGM.OData.Resource()
# Toepassing van de Wet open overheid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c7a67dfc-1ed6-40e8-8c5d-b3739093b77e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c873f37e-a723-4069-beb8-ef17a00fafd9)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7fa42773-6a35-4c8e-8da0-efce043707c3)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(21bdb4b5-4bc7-4f4a-b3c6-065057b2b916)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7c4a3c47-8f13-483e-8674-221180359f2e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(87aacadf-e14d-4dcc-80a3-2fa10e7d6588)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c659001b-1ce8-4161-b430-344c87813f9b)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1ad2ce77-187f-4c0f-abad-7eed4d8cb797)/TK.DA.GGM.OData.Resource()
# Rechtsstaat en Rechtsorde
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(15e48c45-ed82-4b7b-ad13-9c37b4573a22)/TK.DA.GGM.OData.Resource()
# Bedrijfslevenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(699cc3b3-3675-4fb9-9969-ccb8471f372d)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(49cd52ec-4de5-490d-a6ae-2c46749c9c9a)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1232b17d-5fdb-415a-a4f4-4bc8fc035ae9)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(56c730e5-932a-42c2-86ee-58f1e66a291f)/TK.DA.GGM.OData.Resource()
# Werken in het onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(93e6b4bd-7719-4025-bab6-64fa23f0644c)/TK.DA.GGM.OData.Resource()
# JBZ-Raad
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d2c5e5b5-cfec-47f9-85fb-37c9d78d8544)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(41e8516f-5328-4a85-b3e7-322b9698160a)/TK.DA.GGM.OData.Resource()
# Wapenexportbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1266b482-83c1-42b6-a18b-fe53739f2798)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2f267fe9-2bb4-4207-bd9f-17e74783b8f0)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(85f8adc2-3181-4fca-8d5d-6807cb1aa2b7)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(792faaf4-7619-42b5-b1ff-abfabb1ab05b)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6a03b7f1-09cb-47c4-a2ff-e29442169bd8)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d61eab99-6596-4479-9295-09c5e45e6dc1)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9bacebc2-f9eb-4371-80c2-66ec1cc481d0)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4b9042d4-07b7-4be2-9084-b7107f1802d5)/TK.DA.GGM.OData.Resource()
# Integratiebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0116f04e-861a-4785-b151-39f8411000b2)/TK.DA.GGM.OData.Resource()
# Seksuele intimidatie en geweld
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2656bffc-834d-4b94-aad0-c7aaa01a27a9)/TK.DA.GGM.OData.Resource()
# Arbeidsmarktbeleid en opleidingen zorgsector
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(793803ef-26d4-4108-92af-e380bb736613)/TK.DA.GGM.OData.Resource()
# Kansspelen
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f81f1a7a-a4c2-48e3-9159-1e68d13e73d5)/TK.DA.GGM.OData.Resource()
# Vreemdelingenbeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d2ca177-8249-4038-a73c-5a29ad1adb55)/TK.DA.GGM.OData.Resource()
# Spoor: vervoer- en beheerplan
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dcbc10a5-19a0-4c3e-b252-c9d28b775416)/TK.DA.GGM.OData.Resource()
# Raad voor Economische en Financiële Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cdd321d7-8d35-4fa1-82f4-aa870a9560d4)/TK.DA.GGM.OData.Resource()
# Programma Grensverleggende IT (GrIT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(37c6fc09-30d5-4444-be42-18d8b265bd9a)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(31ca69d1-853a-406a-891f-8ec50a4bec2d)/TK.DA.GGM.OData.Resource()
# Raad Algemene Zaken en Raad Buitenlandse Zaken
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(da05004d-3c3d-485c-b1b7-afef5cc88e21)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(806ceaca-0146-40a2-8143-f5e99d0850fd)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0e8cce29-2545-422a-8b8c-c7dd942dc2f0)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e5da58e4-4f33-4c91-9b94-7b8bfeb66947)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0d3dfcaf-9027-422a-a0e6-cb724b09ba82)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8f1cf562-09a4-421e-88e8-d2f5361dea30)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dc1a4870-e57a-4fbf-9bc3-3c643522acd6)/TK.DA.GGM.OData.Resource()
# Waddenzeebeleid
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(699e58c5-4166-4899-b9f9-e18b85fd183e)/TK.DA.GGM.OData.Resource()
# Vaststelling van de begrotingsstaten van het Ministerie van Binnenlandse Zaken en Koninkrijksrelaties (VII) voor het jaar 2024
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b27c6e2c-6dc6-4da2-a796-450dcc23760a)/TK.DA.GGM.OData.Resource()
# Stimulering duurzame energieproductie
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d11e1733-0993-4d44-ae66-62b254ae4b53)/TK.DA.GGM.OData.Resource()
# Voortgezet Onderwijs
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5abe7cf1-e5a1-4848-ba08-990feaf55f5c)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b21299ee-c6f3-4cb9-8187-865840cd64aa)/TK.DA.GGM.OData.Resource()
# Belastingdienst
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bae3234d-bf0e-40dc-b4cf-b4f761b63d1c)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cfa0a2d4-ad14-4f2f-b72d-028598f45b87)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8c34128e-b1ad-4f62-baf8-9a860a569870)/TK.DA.GGM.OData.Resource()
# Informatie- en communicatietechnologie (ICT)
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(22b07d39-3221-4594-9a3f-daffbd0f0d0e)/TK.DA.GGM.OData.Resource()
#
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cfeb7cab-6084-40e3-8838-f5dcec6dc576)/TK.DA.GGM.OData.Resource()
# Integrale visie op de woningmarkt
# https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(13c89793-284e-4b76-a1e5-9bdcd2c8508b)/TK.DA.GGM.OData.Resource()

# %%
commissieverslag_documenten.summary( get_num_items=True )
# Out:
# {'size_bytes': 123170816,
#  'size_readable': '117MiB',
#  'num_items': 858,
#  'avgsize_bytes': 143556,
#  'avgsize_readable': '140KiB'}

# %%
# we have a tool to read PDF and extract chunks of text from it. 
# - this will be explained in more detail elsewhere.
# - we can should fine-tune that extractor to, for this case, remove the headers and footers so you can focus on the real text
# - the following code should be made easier to use
# ...but for now, just a preview:

for url, pdfbytes in commissieverslag_documenten.items():
    print( '======= %s ======='%url )
    splitters = wetsuite.helpers.split.decide(pdfbytes, thresh=500)
    for score, fragproc in splitters: # use each processor that said they would be useful
        frags = fragproc.fragments()
        #for _, _, text in frags:
        #    print( text )
        #    print( '--')
        display( wetsuite.helpers.split.SplitDebug(frags) )

    break # just one document for now (all of them is too much for a notebook to show)
# Out:
# -------------- https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(00011813-1ac7-48b0-93e6-7fab59345d0f)/TK.DA.GGM.OData.Resource() --------------
# <table border="1"><tr><th>meta</th><th>intermediate</th><th>len</th><th>text</th></tr><tr><td style="text-align:left"><pre>{'hints': ['newpage']}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': ['+para'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">32</td><td style="text-align:left">'Tweede Kamer der Staten-Generaal'</td></tr><tr><td style="text-align:left"><pre>{'hints': ['+para'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">2</td><td style="text-align:left">' 2'</td></tr><tr><td style="text-align:left"><pre>{'hints': ['+para'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">23</td><td style="text-align:left">'Vergaderjaar 2020–2021 '</td></tr><tr><td style="text-align:left"><pre>{'hints': ['bold'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">46</td><td style="text-align:left">'32 545 Wet- en regelgeving financiële markten '</td></tr><tr><td style="text-align:left"><pre>{'hints': ['bold'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">65</td><td style="text-align:left">'Nr. 145 VERSLAG VAN EEN COMMISSIEDEBAT  Vastgesteld 28 juli 2021 '</td></tr><tr><td style="text-align:left"><pre>{'hints': ['bold'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">1821</td><td style="text-align:left">'De vaste commissie voor Financiën heeft op 10 juni 2021 overleg gevoerd over: –  de brief van de Minister van Financiën d.d. 18 december 2020 inzake gesprek banken over compensatie bij spoofing (Kamer- stuk 32 545, nr. 128);  –  de brief van de Minister van Financiën d.d. 22 januari 2021 inzake uitkomst aanbesteding giraal betalingsverkeer Rijk (Kamerstuk 26 485, nr. 363);  –  de brief van de Minister van Financiën d.d. 10 februari 2021 inzake voortgang Actieplan Consumentenkeuzes (Kamerstuk 32 013, nr. 246);  –  de brief van de Minister van Financiën d.d. 5 februari 2021 inzake antwoorden op vragen commissie over vier BNC-fiches inzake het Digital Finance Package (onder andere Kamerstuk 22112–2949) (Kamerstuk 22 112, nr. 3048);  –  de brief van de Minister van Financiën d.d. 5 februari 2021 inzake antwoorden op vragen commissie over het fiche: Verordening Markten in Cryptoactiva (MiCA) (Kamerstuk 22112–2937) (Kamerstuk 22 112, nr. 3047);  –  de brief van de Minister van Financiën d.d. 4 maart 2021 inzake antwoorden op vragen commissie inzake faillissement levensverzekeraar Conservatrix (Kamerstuk 29 507, nr. 153);  –  de brief van de Minister van Financiën d.d. 11 februari 2021 inzake vervolg ontwikkelingen consumptiefkredietmarkt (Kamerstukken 24 515 en 32 013, nr. 579);  –  de brief van de Minister van Financiën d.d. 22 februari 2021 inzake kostenvergoeding in verband met de uitspraak Onder- nemingskamer schadeloosstelling onteigening SNS REAAL 2013 (Kamerstuk 33 532, nr. 89);  –  de brief van de Minister van Financiën d.d. 21 april 2021 inzake wetgevingsbrieven DNB en AFM 2021 (Kamerstuk 32 545, nr. 134);  –  de brief van de Minister van Financiën d.d. 20 april 2021 inzake reactie op moties en toezeggingen op het terrein van financiële markten voorjaar 2021 (Kamerstuk 32 545, nr. 133); '</td></tr><tr><td style="text-align:left"><pre>{'hints': ['+para'], 'lastheader': ''}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">107</td><td style="text-align:left">'  kst-32545-145 ISSN 0921 - 7371 ’s-Gravenhage 2021 Tweede Kamer, vergaderjaar 2020–2021, 32 545, nr. 145 1'</td></tr><tr><td style="text-align:left"><pre>{'hints': ['newpage']}</pre></td><td style="text-align:left"><pre>{}</pre></td><td style="text-align:left">0</td><td style="text-align:left">'' ...
